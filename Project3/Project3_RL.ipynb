# %% [markdown]
# # **Project 3 - Reinforcement Learning**

# %% [markdown]
# ## 🌞 Mission: Find a secret Location in Trondheim where SkyNets servers are located

# %% [markdown]
# 📊 **High-level goal:**
#
# Train an agent (the “learner”) to interact with given environment and learn from it, so it can maximize its cumulative rewards over time.
#
#
#
#
# *   **Environment:**
#      *   The environment **is already created** and set up for you with the help of
# "gymnasium" library.
#      *   The agent is interacting with a simulated environment, which has states, accepts actions, and returns rewards. The environment resets at the beginning of each episode, and the agent takes actions within it, receiving feedback in the form of rewards.
# *   **Q-table:**
#      *   This table stores information about the "quality" of actions in different states.
#      *   The goal of the agent is to update the Q-table over time to estimate the value of taking different actions in various states.
#      *   You will initialize and learn Q-table in this project.

# %% [markdown]
# ## 📮 Imports:

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import imageio.v3 as iio
import random
import os

# note: make sure to install necessary libraries like imageio, gymnasium etc.
# !pip install gymnasium

# %%
# import gymnasium stuff
import gymnasium as gym
from gymnasium import error, spaces, utils
from gymnasium.utils import seeding
from gymnasium.spaces import Discrete, MultiDiscrete

# %% [markdown]
# ### Utility functions are provided for you:
#
#
# *   one_hot_decode
# *   one_hot_encode
# *   make_2d
# *   make_3d
# *   read_png_file
# *   is_valid_idx
# *   flatten_observation
# *   is_valid_idx
# *   flatten_observation
# *   make_2d_observation
# *   swap_values

# %%
def one_hot_decode(label_3D):
  """
  Converts back from one-hot encoded format (label_3D)
  to original class labels for each pixel (2D)
  """
  return np.argmax(label_3D, axis=-1)

def one_hot_encode(label_2D, label_values):
    """
    Converts a segmentation image label array (label_2D) to one-hot format
    by replacing each pixel value with a vector of length num_classes
    # Arguments
        label_2D: The 2D array segmentation image label
        label_values: an RGB array of classes (num_classes, 3)

    # Returns
        A 3D array with the same width and height as the input,
        but with a depth size of num_classes (for each pixel)

        Each class gets its own encoding for every pixel in the image.
        Encodings are then stacked along new axis which is number of classes
    """
    semantic_map = []
    for colour in label_values:
        equality = np.equal(label_2D, colour)
        class_map = np.all(equality, axis=-1)
        semantic_map.append(class_map)
    semantic_map = np.stack(semantic_map, axis=-1)

    return semantic_map

def make_2d(map_3d=None, palette_array=None):
    """
    Converts RGB images to images with number of class as value at [i,j]

    map_3d: 3D RGB image (H, W, n_ch = 3)
    palette_array: an RGB array of classes (num_classes, 3)

    Result: 2D structure where each "pixel" in the image
    has a class number instead of RGB color
    """
    # here we make 3D representation, 3rd dimension has one-hot encoded classes
    replaced_image_onehot = one_hot_encode(
        map_3d.astype(np.uint8), palette_array) # size (H, W, num_classes)
    # we create 2D representation, where every pixel has the value of its class
    return one_hot_decode(replaced_image_onehot) # size (H, W) - 2D

def make_3d(map_2d=None, palette_array=None):
    """
    Convert a 2d img to 3d
    Convert a 2D image where each pixel represents a class label
    into a 3D image where each class label is represented
    by its corresponding RGB color from the palette_array.
    Creates colorized 3D image from the original 2D class map

    map_2d: array of class labels, size (H, W)
    palette_array: an RGB array of classes (num_classes, 3)

    Result: RGB image (H, W, 3)
    """
    return palette_array[map_2d.astype(np.uint8)]


def read_png_file(image_path, printDebug = True):
    """
    read a png file and returns it as a 3D numpy array
    """
    original_image_matrix = iio.imread(image_path)

    if original_image_matrix.ndim > 2 and original_image_matrix.shape[-1] > 3:
        if printDebug:
            print(f'image has more than 3 channels, only first 3 channels are used there are {original_image_matrix.shape} channels')
        original_image_matrix = original_image_matrix[:, :, :3]
    return original_image_matrix

def is_valid_idx(image_2D, selected_idx):
    """
    Checks if a given index is within the valid range of a 2D array

    if selected_idx is valid in image_2D
    selected_idx = [i,j]
    image_2D = [h,w]
      """
    if selected_idx[0] < 0 or selected_idx[1] < 0:
        return False
    if selected_idx[0] < image_2D.shape[0]:
        if selected_idx[1] < image_2D.shape[1]:
            return True
    return False

def flatten_observation(observation_arr):
    """
    Converts/flattens a multi-dimensional array into a 1D array
    """
    return observation_arr.flatten


def make_2d_observation(observation_flattened, observation_arr_shape):
    """
    Converts flattened array into shape observation_arr_shape
    """
    return observation_flattened.reshape(observation_arr_shape.shape)

def swap_values(arr, value1, value2):
    """
    Swaps occurencies of two specific values (value1 and value2)
    within a 2D NumPy array (arr).

    arr: A 2D NumPy array where we want to swap the values
    value1: the first value that we want to swap with value2
    value2: the second value that we want to swap with value1

    Returns: 2D array with swapped values
    """

    # Ensure the values are integers
    value1, value2 = int(value1), int(value2)

    # Step 1: Find the first position of value1 and change it to value2
    pos_value1 = np.argwhere(arr == value1) # returns 2D array
    if pos_value1.size > 0:
        arr[pos_value1[0][0], pos_value1[0][1]] = value2

    # Step 2: Get all positions of value2
    pos_value2 = np.argwhere(arr == value2) # returns 2D array

    # Step 3: Randomly select a position of value2 that is not the original value1's position
    if len(pos_value2) > 1:
        # filter out the position of former value1 (pos_value1) which now also contains value2
        pos_value2 = pos_value2[np.all(pos_value2 != pos_value1[0], axis=1)]
        if pos_value2.size > 0:
            random_pos_value2 = pos_value2[np.random.choice(len(pos_value2))]
            arr[random_pos_value2[0], random_pos_value2[1]] = value1

    return arr

# %% [markdown]
# ### Environment class with necessary functions - provided for you:
#
#
# *   constructor __init__
# *   step
# *   reset
# *   get_1d_state
# *   render
# *   close

# %%
class TrondheimEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, conf):
        """
        Every environment should be derived from gym.Env and at least contain
        variables observation_space and action_space specifying the type of possible
        observations and actions using spaces.Box or spaces.Discrete.

        Example:
        >>> EnvTest = TrondheimEnv()
        >>> EnvTest.observation_space=spaces.Box(low=-1, high=1, shape=(3,4))
        >>> EnvTest.action_space=spaces.Discrete(2)
        """

        self.manual_mode = True  # Flag to control printouts

        # action definition:
        number_action = 4
        self.action_space = Discrete(number_action)

        self.env_image_path = conf['env_image_path']
        self.number_removable_locations = conf['number_removable_locations']

        self.pallete = np.array([[0, 0, 255],    # Blue:0:Water
                            [255, 255, 0],  # Yellow:1:Start
                            [0, 255, 0],    # Green:2:Land
                            [255, 0, 0],    # Red:3:BusLane
                            [128, 0, 128],  # Purple:4:BusStop
                            [0,   0,   0],  # Black:5:Secret Location
                            [128, 128, 0]], # Olive:6:Final Location
                           dtype=np.uint8)

        self.neighbours = np.array([[-1,0],[0,-1],[1,0],[0,1]]) # up, left, down, right
        self.not_allowed_area = [0] # water
        self.normal_land_class = 2 # land
        self.neutral_area = [self.normal_land_class,3] # land and BusLane
        self.start_class = 1 # start
        self.busstop_class = 4 # bus stop
        self.secret_location_class = 5 # secret location
        self.final_location_class = 6 # final location (2)

        # does agent die when enter not_allowed_area
        self.dead_allowed = conf['dead_allowed']
        # does shops closed after the first purchase
        self.remove_after_location_found = conf['remove_after_location_found']
        # should we start at different place each time
        self.start_random = conf['start_random']

        # read RGB image into a 3D numpy array
        img_3d = read_png_file(self.env_image_path, printDebug = False)

        # convert RGB image into 2D semantic class representation
        img_2d = make_2d(map_3d=img_3d,
                         palette_array=self.pallete)

        # the current state of the environment
        self.observation = img_2d # initial observation - 2D semantic class
        # copy of the environment's initial state before any actions have been taken
        self.initial_observation = img_2d.copy()

        max_observation_value = np.max(img_2d)
        # assert isinstance(max_observation_value, int)
        # can be used, not needed for this implementation
        # observation space is a gym object (MultiDiscrete), like numpy array. It can be sampled
        observation_space = np.full_like(img_2d,
                                         fill_value=max_observation_value)
        self.observation_space = MultiDiscrete(observation_space)

        # rewards
        self.reward = 0

        # done
        self.done = False

        # terminated
        self.terminated = False




    def step(self, action):
        """
        This method is the primary interface between environment and agent.

        Parameters:
            action: int
                    the index of the respective action (if action space is discrete)

        Returns:
            output: (array, float, bool, info)
                    information provided by the environment about its current state:
                    (observation, reward, done)

                    self.observation: The updated state of the environment (2D)
                    reward: Reward agent received for the action in this step (Int)
                    terminated: indicate if the episode has ended (Bool)
                    info: Additional information (not used currently)

        """
        obs = self.observation # 2D array of semantic class image representation
        terminated = False
        truncated = False
        info = None
        done = False

        # just start and see where it goes
        start_idx = np.argwhere(obs == self.start_class)[0]
        # action is: 0:up, 1:left, 2:down, 3:right
        next_idx = start_idx + self.neighbours[action]
        reward = self.reward
        if self.manual_mode:
          print('Next step towards: ')

        if not is_valid_idx(image_2D=obs, selected_idx=next_idx):
            next_idx = start_idx
            if self.manual_mode:
                print('Hey there, you cannot escape outside of the environment')

        # now decide what happens next

        if obs[tuple(next_idx)] == self.normal_land_class:
            if self.manual_mode:
                print('Green Land class area')

        # check if it is a non allowed area
        if obs[tuple(next_idx)] in self.not_allowed_area:
            if self.manual_mode:
                print('The move is not allowed')
            if self.dead_allowed:
                # penalize the agent if allowed to die. Terminate
                reward = -1000
                terminated = True
            else:
                # if NOT allowed to die, reset the next position to current one - prevent the move
                next_idx = start_idx


        # if the player is in bus stup
        elif obs[tuple(next_idx)] == self.busstop_class:
            if self.manual_mode:
                print('A bus stop')

            # get the bus stop that is not the next step
            bus_stop_indices = np.argwhere(obs == self.busstop_class)
            # flip the next state to the other side of the stop
            if np.array_equal(next_idx, bus_stop_indices[0]):
                # teleport the agent from bus stop 0 to bus stop 1
                next_idx = bus_stop_indices[1]
            else:
                # teleport the agent from bus stop 1 to bus stop 0
                next_idx = bus_stop_indices[0]

        # if it is Secret Location
        elif obs[tuple(next_idx)] == self.secret_location_class:
            if self.manual_mode:
                print('Central Source Secret Location')
            reward = 300
            # close the shop (remove from the map)
            if self.remove_after_location_found:
                self.initial_observation[tuple(next_idx)] = self.normal_land_class
                self.observation[tuple(next_idx)] = self.normal_land_class
                self.number_removed_shop += 1
                reward = 9000

        # and the Final Location
        elif obs[tuple(next_idx)] == self.final_location_class:
            if self.manual_mode:
                print('Final Location - well done!')
                print('You have discovered the Final Location of AI center in Trondheim')
            terminated = True
            done = True
            reward += 200


        # now we need to change the observation space
        # i.e. update the environment’s state to reflect the agent's movement

        # if agent’s current position was initial start position
        if self.initial_observation[tuple(start_idx)] == self.start_class:
            # if true, update observation - mark the start position as neutral area
            self.observation[tuple(start_idx)] = self.normal_land_class
        else:
            # if current position not the initial start one
            # restores position in self.observation to its original value from self.initial_observation
            # re-color the observation as where you were if not start position
            self.observation[tuple(start_idx)] = self.initial_observation[tuple(start_idx)]

        # sets the new position of the agent as the next start position
        self.observation[tuple(next_idx)] = self.start_class

        return self.observation, reward, terminated, info


    def reset(self):
        """
        This method resets the environment to its initial values.

        Returns:
            observation:    array
                            the initial state of the environment
        """
        self.number_removed_shop = 0

        img_3d = read_png_file(self.env_image_path, printDebug = False)
        img_2d = make_2d(map_3d=img_3d,
                         palette_array=self.pallete)

        if self.start_random:
          # we need to move the start to another place
          img_2d = swap_values(arr=img_2d,
                               value1=1,
                               value2=2)

        self.observation = img_2d
        self.initial_observation = img_2d.copy()

        max_observation_value = np.max(img_2d)
        observation_space = np.full_like(img_2d,
                                         fill_value=max_observation_value)
        self.observation_space = MultiDiscrete(observation_space)

        # rewards
        self.reward = 0

        # done
        self.done = False

        # terminated
        self.terminated = False

        return self.observation


    def get_1d_state(self):
        """
        This function returns state as 1d observation
        """
        max_x = self.observation.shape[0]
        max_y = self.observation.shape[1]

        start_idx = np.argwhere(
            self.observation == self.start_class)[0]
        state_number = (
            start_idx[0] * max_x) + start_idx[1]
        state_number = (self.number_removed_shop * max_x * max_y) + state_number
        return state_number

    def render(self, mode='human', close=False):
        """
        This methods provides the option to render the environment's behavior to a
        window which should be readable to the human eye if mode is set to 'human'.
        """
        render_ready_arr = make_3d(map_2d=self.observation,
                                   palette_array=self.pallete)
        plt.imshow(render_ready_arr)
        plt.show()
        plt.close()
        return render_ready_arr

    def close(self):
        """
        This method provides the user with the option to perform necessary
        cleanup.
        """
        img_3d = read_png_file(self.env_image_path)
        img_2d = make_2d(map_3d=img_3d,
                         palette_array=self.pallete)
        self.observation = img_2d
        self.initial_observation = img_2d.copy()

# %%
# let's make sure to create subfolder for our input images, if not already there
input_folder = 'input_images'
if not os.path.exists(input_folder):
    os.makedirs(input_folder)

# %% [markdown]
# # Configuring and loading the environment:

# %% [markdown]
# ## 🔎📉  Let's first visualize our simple toy environment

# %%
# This is how you create a configuration for the environment
# Note: make sure that folder input_images is created
# Note 2: make sure you copy necessary input images there

env_config = {
    'env_image_path':'input_images/image_simple_1.png',
    'dead_allowed':False,
    'remove_after_location_found':False,
    'start_random':False,
    'number_removable_locations':0,
}


if not os.path.exists(env_config['env_image_path']):
  # make sure you have the folder and the image
  print(f"Error: The image path {env_config['env_image_path']} does not exist.")
else:
  # if everything fine, we create the environment
  tmp_env = TrondheimEnv(conf=env_config)
  print(f"Environment successfully created")
# Out:
# Environment successfully created

# %%
# visualize the environment. Yellow is where we are, Black is where we want to go
tmp_env.reset()
tmp_env.render()
# Out:
# array([[[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0,   0,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [255, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)

# %% [markdown]
# Let's see how actions work:

# %%
action_dict = {
    'up':0,
    'left':1,
    'down':2,
    'right':3,
}

# %%
# select your action here
# you are encouraged to play further with this
my_action = 'left'

# now take a step through the environment by taking this action
obs, rew, term, info = tmp_env.step(action_dict[my_action])
print(f"Reward for action {my_action} is: {rew}")
tmp_env.render()

print(f"Observation space looks like this:\n{obs}")
# Out:
# Next step towards:
# Green Land class area
# Reward for action left is: 0
# Observation space looks like this:
# [[2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 5 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]
#  [2 2 2 2 2 2 2 2 2 1 2 2]
#  [2 2 2 2 2 2 2 2 2 2 2 2]]

# %% [markdown]
# # 🧠 **Your Assignments**

# %% [markdown]
# # 1️⃣ Assignment 1: Q-learning with simple toy environment

# %% [markdown]
# ## 🐣 Let's learn how to do this in a simple environment
#
#
# *   Task 1: Initialize Q table
# *   Task 2: Write necessary helper functions for Q-learning
# *   Task 3: Play with Hyperparameters
# *   Task 4: Train the agent using Q-learning
#
# **Note**: Task 2, Task 3 and Task 4: you will use the same code you implemented for these in the Assignment 2.

# %%
# Environment is set up for you here
env_config = {
    'env_image_path':'input_images/image_simple_1.png',
    'dead_allowed':False,
    'remove_after_location_found':False,
    'start_random':False,
    'number_removable_locations':0,
}

if not os.path.exists(env_config['env_image_path']):
  # make sure you have the folder and the image
  print(f"Error: The image path {env_config['env_image_path']} does not exist.")
else:
  # if everything fine, we create the environment
  tmp_env = TrondheimEnv(conf=env_config)
  print(f"Environment successfully created")
# Out:
# Environment successfully created

# %% [markdown]
# ### Task 1: Initialize Q table

# %%
# Task 1: Initialize Q table
"""
TODO: given the environment, initialize the Q table
"""
# The board is 12x12, and there are no removable locations
n_states = 12*12

n_actions = tmp_env.action_space.n 

Q_table = np.zeros((n_states, n_actions))

# Tip: pay attention to the dimensions of Q table
# Tip: how many states does the table have, how many actions

print(f"Observation space dimensions:  {tmp_env.observation_space.shape}")
print(f"Number of possible actions: {tmp_env.action_space.n}")

# YOUR CODE GOES HERE
Q_test = np.zeros((n_states,n_actions)) # you need to initialize this variable
Q_test += 1e-6 * np.random.randn(*Q_test.shape)
#print(Q_test.shape)
# Out:
# Observation space dimensions:  (12, 12)
# Number of possible actions: 4

# %%
# take a look into initial Q table (randomized one)
print(f"Q table has this shape: {Q_test.shape}\n")

# you may want to print Q table, or parts of it, to get the vibe
print(Q_test[:10])
print(f"\n")
#print(Q_test[135:])
# Out:
# Q table has this shape: (144, 4)
#
# [[-7.25911239e-07 -2.22117103e-07  5.36226165e-07  1.93292699e-07]
#  [-8.55259754e-07  1.42699529e-06  5.61487050e-07 -1.43165749e-07]
#  [-1.11011269e-06  4.96258105e-07  8.52214125e-07  4.10359600e-07]
#  [-1.64201480e-06 -1.47815661e-07  1.47927044e-06  6.64782864e-07]
#  [-8.48643701e-07  7.25076969e-07  7.23011366e-07  4.73553316e-07]
#  [-2.24227349e-07 -2.19849905e-07  5.38064308e-07  1.28586714e-06]
#  [-2.48232589e-07  5.61887875e-07  2.44870109e-06 -1.05888880e-06]
#  [ 1.55638942e-06  2.37209805e-07 -1.54814387e-06  2.37525078e-07]
#  [ 9.05853283e-07 -1.83502214e-06 -5.94465719e-07 -2.71397403e-07]
#  [ 1.45757006e-07 -3.56480167e-07 -4.01553871e-07 -4.93222221e-07]]

# %% [markdown]
# ### Task 2: Write necessary helper functions for Q-learning

# %%
# Task 2: Write necessary helper functions for Q-learning
"""
TODO: write helper function to:
 update_explore_rate() - controls the balance between exploration and exploitation
 update_learning_rate() - controls how aggressively the agent updates its knowledge

 update_action() - uses the exploration rate to decide whether to take a
 random action (explore) or to act according to the learned Q-values (exploit)
"""

decay_factor = 0.995
start_explore_rate = 0.995  
start_learning_rate = 0.7

# Explore Rate Decay Function, Converges to MIN_EXPLORE_RATE
def update_explore_rate(episode, MIN_EXPLORE_RATE):
    # this function should return updated explore_rate
	# YOUR CODE GOES HERE    
  explore_rate = max(MIN_EXPLORE_RATE, start_explore_rate * (decay_factor ** episode))
  return explore_rate

# Learning Rate Decay Function, Converges to MIN_LEARNING_RATE
def update_learning_rate(episode, MIN_LEARNING_RATE):
    # this function should return updated learning_rate
	# YOUR CODE GOES HERE
    learning_rate = max(MIN_LEARNING_RATE, start_learning_rate * (decay_factor ** episode))
    return learning_rate

# returns an action based on current state, explore rate and Q table
def update_action(env, state, explore_rate, Q):

    # If a random number between 0 and 1 is less than explore_rate,
    # we explore, else we exploit
    if random.uniform(0, 1) < explore_rate:
        action = env.action_space.sample()
    else:
        action = np.argmax(Q[state, :])
    return action

# %% [markdown]
# ### Task 3: Play with Hyperparameters

# %%
# Task 3: Play with Hyperparameters

# YOUR CODE GOES HERE: replace None with your values
GAMMA_test = 0.5
NUM_EPISODES_test = 128
MIN_EXPLORE_RATE_test = 0.1
MIN_LEARNING_RATE_test = 0.2
STEP_SIZE_TEST = 0.1
MAX_STEPS_PER_EPISODE = 100

# %% [markdown]
# ## 🐤 Now use Q learning to learn the Q table
# ### Task 4: Train the agent using Q-learning

# %% [markdown]
# The Q-value update equation, derived from Bellman equation is as follows:

# %% [markdown]
# $$
# Q(s, a) \gets Q(s, a) + \alpha*\Big[ R(s, a) + \gamma* \max_{a'} Q(s', a') - Q(s, a) \Big]
# $$

# %% [markdown]
# **Legend:**
#
# - **Q(s, a)**: Action-value function, estimating the expected return for taking action *a* in state *s*
# - **α**: learning rate
# - **R(s, a)**: reward received after taking action *a* in state *s*
# - **γ**: discount factor (importance of future rewards)
# - **s'**: Next state resulting from taking action *a* in state *s*
# - **a'**: Possible actions in the next state *s'*
# - **max Q(s', a')**: Maximum estimated Q value of the next state over all possible actions *a'*

# %%
# Task 4: Train the agent using Q-learning
# Suggestion: you can wrap the code to learn Q-table in a function,
# which you can also use for Task 4 in Assignment 2

# result of the training is:
#   updated Q table (Q_test)
#   total_reward
#   you are free to add others, if you will

tmp_env.manual_mode = False # disable printouts while training


# initialize some variables
total_reward = 0

explore_rate = update_explore_rate(0, MIN_EXPLORE_RATE=MIN_EXPLORE_RATE_test)
learning_rate = update_learning_rate(0, MIN_LEARNING_RATE=MIN_LEARNING_RATE_test)

rewards_per_episode = []
succesfull_episodes = 0
last_successcful_episode = 0
# Training loop
for episode in range(NUM_EPISODES_test):
    # reset environment at start of each episode
    obs = tmp_env.reset()
    # get initial state as 1D
    state = tmp_env.get_1d_state()
    # reset total reward for this episode
    reward = 0

    # Update explore rate and learning rate each episode
    explore_rate = update_explore_rate(episode, MIN_EXPLORE_RATE_test)
    learning_rate = update_learning_rate(episode, MIN_LEARNING_RATE_test)

    # Step through the environment for a number of steps
    for step in range(MAX_STEPS_PER_EPISODE):  # limit number of steps per episode
        # select action based on current state, explore rate and Q table
        action = update_action(tmp_env, state, explore_rate, Q_test)
        print(f"Episode {episode}, Action {action}")
        # take action and observe next state and reward
        next_obs, reward, terminated, info = tmp_env.step(action)
        # get next state as 1D
        next_state = tmp_env.get_1d_state()
        if terminated:
            succesfull_episodes += 1
            last_successcful_episode = episode
            
            print(f"Episode {episode} reached the final location!")
            Q_test[state, action] += learning_rate * (
            reward + GAMMA_test * Q_test[next_state, best_next_action] - Q_test[state, action]
            )
            break
        # Evaluate best next action from next state
        best_next_action = np.argmax(Q_test[next_state, :])
        # update total reward
        Q_test[state, action] += learning_rate * (
            reward + GAMMA_test * Q_test[next_state, best_next_action] - Q_test[state, action]
        )
        state = next_state
    total_reward += reward
    rewards_per_episode.append(total_reward)
    print(f"Episode: {episode}  Total reward: {total_reward:.2f}  Explore rate: {explore_rate:.3f}")

print("Training complete!")
print("Final Q-table sample:")
print(Q_test[:5])
print(f"Number of successful episodes: {succesfull_episodes} out of {NUM_EPISODES_test}")
print(f"Last successful episode: {last_successcful_episode}")
print(f"Total reward over all episodes: {total_reward}")
# Tip: iterate over number of episodes

    # Tip: iterate over number of steps in each Episode
    # Tip: use helper functions defined above to navigate the environment

        # Tip: use the Q-learning update rule equation - Bellman equation



  # Tip : print variables of interest, like episode, total_reward, explore_rate
  # print(f"Episode :{i}  Total_reward: {total_reward}  Explore rate: {explore_rate}")
  #print("Final Q values: ", Q_test)
# Out:
# Episode 0, Action 2
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 1
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 2
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 2
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 0
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 1
# Episode 0, Action 1
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 0
# Episode 0, Action 1
# Episode 0, Action 1
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 2
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 3
# Episode 0, Action 0
# Episode 0, Action 3
# Episode 0, Action 3
# Episode 0, Action 1
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 1
# Episode 0, Action 1
# Episode 0, Action 1
# Episode 0, Action 2
# Episode 0, Action 2
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 3
# Episode 0, Action 2
# Episode 0, Action 1
# Episode 0, Action 0
# Episode 0, Action 1
# Episode 0, Action 3
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 0
# Episode 0, Action 1
# Episode 0, Action 0
# Episode 0, Action 3
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 0
# Episode 0, Action 0
# Episode 0, Action 2
# Episode 0, Action 3
# Episode 0, Action 2
# Episode 0, Action 2
# Episode 0, Action 2
# Episode 0, Action 1
# Episode 0, Action 3
# Episode: 0  Total reward: 0.00  Explore rate: 0.995
# Episode 1, Action 3
# Episode 1, Action 0
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 0
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 0
# Episode 1, Action 1
# Episode 1, Action 3
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 3
# Episode 1, Action 3
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 3
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 3
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 1
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 2
# Episode 1, Action 3
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 1
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 2
# Episode 1, Action 3
# Episode 1, Action 0
# Episode 1, Action 2
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 3
# Episode 1, Action 3
# Episode 1, Action 3
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 1
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 3
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 1
# Episode 1, Action 3
# Episode 1, Action 0
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 0
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 3
# Episode 1, Action 3
# Episode 1, Action 3
# Episode 1, Action 2
# Episode 1, Action 3
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 1
# Episode 1, Action 0
# Episode 1, Action 3
# Episode 1, Action 2
# Episode 1, Action 0
# Episode 1, Action 0
# Episode 1, Action 3
# Episode 1, Action 2
# Episode 1, Action 3
# Episode 1, Action 1
# Episode 1, Action 2
# Episode 1, Action 0
# Episode: 1  Total reward: 0.00  Explore rate: 0.990
# Episode 2, Action 3
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 0
# Episode 2, Action 3
# Episode 2, Action 2
# Episode 2, Action 2
# Episode 2, Action 0
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 2
# Episode 2, Action 0
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 3
# Episode 2, Action 2
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 2
# Episode 2, Action 0
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 0
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 3
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 0
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 3
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 2
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 3
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 2
# Episode 2, Action 3
# Episode 2, Action 3
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 2
# Episode 2, Action 1
# Episode 2, Action 1
# Episode 2, Action 0
# Episode 2, Action 1
# Episode 2, Action 3
# Episode 2, Action 0
# Episode 2, Action 0
# Episode: 2  Total reward: 0.00  Explore rate: 0.985
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 1
# Episode 3, Action 1
# Episode 3, Action 1
# Episode 3, Action 0
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 1
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 1
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 0
# Episode 3, Action 1
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 1
# Episode 3, Action 1
# Episode 3, Action 2
# Episode 3, Action 1
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 1
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 0
# Episode 3, Action 0
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 2
# Episode 3, Action 1
# Episode 3, Action 2
# Episode 3, Action 3
# Episode 3, Action 3
# Episode 3, Action 1
# Episode 3, Action 3
# Episode 3, Action 0
# Episode 3, Action 2
# Episode 3, Action 0
# Episode 3, Action 1
# Episode: 3  Total reward: 0.00  Explore rate: 0.980
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 1
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 2
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 2
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 1
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 1
# Episode 4, Action 2
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 2
# Episode 4, Action 2
# Episode 4, Action 1
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 1
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 1
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 1
# Episode 4, Action 3
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 2
# Episode 4, Action 1
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 2
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 2
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 1
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 1
# Episode 4, Action 3
# Episode 4, Action 1
# Episode 4, Action 0
# Episode 4, Action 2
# Episode 4, Action 0
# Episode 4, Action 3
# Episode 4, Action 3
# Episode 4, Action 0
# Episode 4, Action 1
# Episode 4, Action 2
# Episode 4, Action 3
# Episode 4, Action 2
# Episode: 4  Total reward: 0.00  Explore rate: 0.975
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 3
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 2
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 2
# Episode 5, Action 2
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 2
# Episode 5, Action 2
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 3
# Episode 5, Action 0
# Episode 5, Action 2
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 2
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 1
# Episode 5, Action 2
# Episode 5, Action 3
# Episode 5, Action 0
# Episode 5, Action 2
# Episode 5, Action 0
# Episode 5, Action 3
# Episode 5, Action 1
# Episode 5, Action 0
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 3
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 2
# Episode 5, Action 2
# Episode 5, Action 0
# Episode 5, Action 1
# Episode 5, Action 1
# Episode 5, Action 3
# Episode 5, Action 2
# Episode 5, Action 1
# Episode: 5  Total reward: 0.00  Explore rate: 0.970
# Episode 6, Action 0
# Episode 6, Action 1
# Episode 6, Action 0
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 2
# Episode 6, Action 0
# Episode 6, Action 0
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 0
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 0
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 0
# Episode 6, Action 0
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 3
# Episode 6, Action 0
# Episode 6, Action 0
# Episode 6, Action 0
# Episode 6, Action 2
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 0
# Episode 6, Action 1
# Episode 6, Action 0
# Episode 6, Action 2
# Episode 6, Action 0
# Episode 6, Action 0
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 2
# Episode 6, Action 1
# Episode 6, Action 3
# Episode 6, Action 1
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 0
# Episode 6, Action 1
# Episode 6, Action 2
# Episode 6, Action 3
# Episode 6, Action 3
# Episode 6, Action 3
# Episode: 6  Total reward: 0.00  Explore rate: 0.966
# Episode 7, Action 0
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 2
# Episode 7, Action 1
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 3
# Episode 7, Action 2
# Episode 7, Action 0
# Episode 7, Action 3
# Episode 7, Action 2
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 2
# Episode 7, Action 2
# Episode 7, Action 1
# Episode 7, Action 1
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 2
# Episode 7, Action 0
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 2
# Episode 7, Action 2
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 0
# Episode 7, Action 1
# Episode 7, Action 1
# Episode 7, Action 1
# Episode 7, Action 0
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 0
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 3
# Episode 7, Action 0
# Episode 7, Action 0
# Episode 7, Action 3
# Episode 7, Action 1
# Episode 7, Action 2
# Episode 7, Action 2
# Episode 7, Action 2
# Episode: 7  Total reward: 0.00  Explore rate: 0.961
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 3
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 3
# Episode 8, Action 0
# Episode 8, Action 3
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 0
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 0
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 2
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 1
# Episode 8, Action 0
# Episode 8, Action 0
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 0
# Episode 8, Action 0
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 0
# Episode 8, Action 3
# Episode 8, Action 3
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 0
# Episode 8, Action 3
# Episode 8, Action 0
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 1
# Episode 8, Action 3
# Episode 8, Action 3
# Episode 8, Action 1
# Episode 8, Action 2
# Episode 8, Action 2
# Episode 8, Action 3
# Episode 8, Action 2
# Episode: 8  Total reward: 0.00  Explore rate: 0.956
# Episode 9, Action 0
# Episode 9, Action 2
# Episode 9, Action 1
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 2
# Episode 9, Action 1
# Episode 9, Action 3
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 1
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 1
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 3
# Episode 9, Action 1
# Episode 9, Action 2
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 2
# Episode 9, Action 1
# Episode 9, Action 1
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 1
# Episode 9, Action 2
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 1
# Episode 9, Action 3
# Episode 9, Action 1
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 1
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 2
# Episode 9, Action 0
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 1
# Episode 9, Action 2
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 2
# Episode 9, Action 1
# Episode 9, Action 1
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 3
# Episode 9, Action 1
# Episode 9, Action 2
# Episode 9, Action 1
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 1
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 3
# Episode 9, Action 3
# Episode 9, Action 2
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 1
# Episode 9, Action 1
# Episode 9, Action 3
# Episode 9, Action 3
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 0
# Episode 9, Action 2
# Episode 9, Action 3
# Episode 9, Action 3
# Episode 9, Action 3
# Episode: 9  Total reward: 0.00  Explore rate: 0.951
# Episode 10, Action 2
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 0
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 1
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 3
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 2
# Episode 10, Action 0
# Episode 10, Action 2
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 2
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 3
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 3
# Episode 10, Action 0
# Episode 10, Action 0
# Episode 10, Action 1
# Episode 10, Action 2
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 2
# Episode 10, Action 0
# Episode 10, Action 2
# Episode 10, Action 1
# Episode 10, Action 3
# Episode 10, Action 1
# Episode 10, Action 0
# Episode 10, Action 0
# Episode 10, Action 3
# Episode: 10  Total reward: 0.00  Explore rate: 0.946
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 0
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 3
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 3
# Episode 11, Action 3
# Episode 11, Action 3
# Episode 11, Action 3
# Episode 11, Action 3
# Episode 11, Action 1
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 2
# Episode 11, Action 2
# Episode 11, Action 2
# Episode 11, Action 3
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 0
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 0
# Episode 11, Action 3
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 2
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 1
# Episode 11, Action 3
# Episode 11, Action 2
# Episode 11, Action 1
# Episode 11, Action 0
# Episode 11, Action 1
# Episode: 11  Total reward: 0.00  Explore rate: 0.942
# Episode 12, Action 0
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 2
# Episode 12, Action 0
# Episode 12, Action 0
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 2
# Episode 12, Action 0
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 2
# Episode 12, Action 2
# Episode 12, Action 0
# Episode 12, Action 2
# Episode 12, Action 2
# Episode 12, Action 3
# Episode 12, Action 2
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 0
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 0
# Episode 12, Action 1
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 3
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 2
# Episode 12, Action 0
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 2
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 0
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 2
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 3
# Episode 12, Action 0
# Episode 12, Action 0
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 0
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 3
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 3
# Episode 12, Action 2
# Episode 12, Action 0
# Episode 12, Action 2
# Episode 12, Action 3
# Episode 12, Action 0
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 2
# Episode 12, Action 3
# Episode 12, Action 2
# Episode 12, Action 2
# Episode 12, Action 1
# Episode 12, Action 1
# Episode 12, Action 0
# Episode 12, Action 1
# Episode: 12  Total reward: 0.00  Explore rate: 0.937
# Episode 13, Action 2
# Episode 13, Action 3
# Episode 13, Action 1
# Episode 13, Action 1
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 2
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 3
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 2
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 2
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 3
# Episode 13, Action 3
# Episode 13, Action 0
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 1
# Episode 13, Action 3
# Episode 13, Action 1
# Episode 13, Action 2
# Episode 13, Action 2
# Episode 13, Action 2
# Episode 13, Action 2
# Episode 13, Action 3
# Episode 13, Action 3
# Episode 13, Action 3
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 0
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 2
# Episode 13, Action 0
# Episode 13, Action 1
# Episode 13, Action 1
# Episode 13, Action 1
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 3
# Episode 13, Action 1
# Episode 13, Action 0
# Episode 13, Action 3
# Episode 13, Action 3
# Episode 13, Action 0
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 3
# Episode 13, Action 2
# Episode 13, Action 2
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 2
# Episode 13, Action 0
# Episode 13, Action 2
# Episode 13, Action 1
# Episode 13, Action 0
# Episode: 13  Total reward: 0.00  Explore rate: 0.932
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 0
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 3
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 0
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 3
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 1
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 1
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 0
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 3
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 3
# Episode 14, Action 3
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 3
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 2
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 3
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 0
# Episode 14, Action 3
# Episode 14, Action 1
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 3
# Episode 14, Action 3
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 0
# Episode 14, Action 0
# Episode 14, Action 2
# Episode 14, Action 1
# Episode 14, Action 1
# Episode 14, Action 2
# Episode 14, Action 3
# Episode 14, Action 3
# Episode 14, Action 0
# Episode 14, Action 2
# Episode 14, Action 0
# Episode: 14  Total reward: 0.00  Explore rate: 0.928
# Episode 15, Action 3
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 3
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 3
# Episode 15, Action 0
# Episode 15, Action 1
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 3
# Episode 15, Action 3
# Episode 15, Action 3
# Episode 15, Action 1
# Episode 15, Action 1
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 3
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 3
# Episode 15, Action 1
# Episode 15, Action 3
# Episode 15, Action 0
# Episode 15, Action 3
# Episode 15, Action 3
# Episode 15, Action 2
# Episode 15, Action 3
# Episode 15, Action 0
# Episode 15, Action 1
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 3
# Episode 15, Action 3
# Episode 15, Action 1
# Episode 15, Action 0
# Episode 15, Action 3
# Episode 15, Action 3
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 1
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 3
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 3
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 0
# Episode 15, Action 0
# Episode 15, Action 2
# Episode 15, Action 2
# Episode 15, Action 3
# Episode 15, Action 1
# Episode 15, Action 0
# Episode 15, Action 1
# Episode 15, Action 2
# Episode 15, Action 2
# Episode: 15  Total reward: 0.00  Explore rate: 0.923
# Episode 16, Action 1
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 0
# Episode 16, Action 0
# Episode 16, Action 2
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 3
# Episode 16, Action 0
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 3
# Episode 16, Action 1
# Episode 16, Action 1
# Episode 16, Action 3
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 3
# Episode 16, Action 3
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 3
# Episode 16, Action 3
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 0
# Episode 16, Action 3
# Episode 16, Action 0
# Episode 16, Action 0
# Episode 16, Action 0
# Episode 16, Action 0
# Episode 16, Action 2
# Episode 16, Action 2
# Episode 16, Action 3
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 2
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 0
# Episode 16, Action 1
# Episode 16, Action 2
# Episode 16, Action 3
# Episode 16, Action 3
# Episode 16, Action 2
# Episode 16, Action 1
# Episode 16, Action 3
# Episode: 16  Total reward: 0.00  Explore rate: 0.918
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 2
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 3
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 2
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 2
# Episode 17, Action 2
# Episode 17, Action 2
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 2
# Episode 17, Action 0
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 0
# Episode 17, Action 2
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 3
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 2
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 1
# Episode 17, Action 1
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 0
# Episode 17, Action 1
# Episode 17, Action 2
# Episode 17, Action 2
# Episode 17, Action 3
# Episode 17, Action 2
# Episode: 17  Total reward: 0.00  Explore rate: 0.914
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 2
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 2
# Episode 18, Action 0
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 0
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 2
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 3
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 2
# Episode 18, Action 2
# Episode 18, Action 2
# Episode 18, Action 1
# Episode 18, Action 3
# Episode 18, Action 2
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 0
# Episode 18, Action 3
# Episode 18, Action 0
# Episode 18, Action 0
# Episode 18, Action 1
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 1
# Episode 18, Action 2
# Episode 18, Action 3
# Episode 18, Action 3
# Episode 18, Action 1
# Episode 18, Action 0
# Episode 18, Action 2
# Episode 18, Action 0
# Episode: 18  Total reward: 0.00  Explore rate: 0.909
# Episode 19, Action 2
# Episode 19, Action 3
# Episode 19, Action 1
# Episode 19, Action 1
# Episode 19, Action 0
# Episode 19, Action 0
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 0
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 0
# Episode 19, Action 1
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 3
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 0
# Episode 19, Action 2
# Episode 19, Action 3
# Episode 19, Action 1
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 0
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 3
# Episode 19, Action 1
# Episode 19, Action 0
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 3
# Episode 19, Action 3
# Episode 19, Action 2
# Episode 19, Action 3
# Episode 19, Action 3
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 3
# Episode 19, Action 2
# Episode 19, Action 3
# Episode 19, Action 1
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 1
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 1
# Episode 19, Action 0
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 3
# Episode 19, Action 2
# Episode 19, Action 2
# Episode 19, Action 1
# Episode 19, Action 3
# Episode 19, Action 0
# Episode 19, Action 1
# Episode 19, Action 0
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 2
# Episode 19, Action 0
# Episode 19, Action 0
# Episode 19, Action 3
# Episode 19, Action 3
# Episode 19, Action 3
# Episode 19, Action 0
# Episode 19, Action 1
# Episode 19, Action 1
# Episode 19, Action 3
# Episode 19, Action 2
# Episode 19, Action 2
# Episode: 19  Total reward: 0.00  Explore rate: 0.905
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 1
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 2
# Episode 20, Action 1
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 1
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 1
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 1
# Episode 20, Action 1
# Episode 20, Action 2
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 0
# Episode 20, Action 3
# Episode 20, Action 3
# Episode 20, Action 1
# Episode 20, Action 1
# Episode 20, Action 3
# Episode 20, Action 1
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 2
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 3
# Episode 20, Action 3
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 1
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 1
# Episode 20, Action 1
# Episode 20, Action 3
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 1
# Episode 20, Action 2
# Episode 20, Action 0
# Episode 20, Action 3
# Episode 20, Action 2
# Episode 20, Action 2
# Episode 20, Action 1
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 2
# Episode 20, Action 0
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 1
# Episode 20, Action 1
# Episode 20, Action 3
# Episode 20, Action 2
# Episode 20, Action 0
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 0
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 2
# Episode 20, Action 3
# Episode 20, Action 2
# Episode 20, Action 1
# Episode 20, Action 0
# Episode 20, Action 3
# Episode 20, Action 0
# Episode 20, Action 0
# Episode 20, Action 0
# Episode 20, Action 1
# Episode 20, Action 0
# Episode: 20  Total reward: 0.00  Explore rate: 0.900
# Episode 21, Action 2
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 3
# Episode 21, Action 3
# Episode 21, Action 1
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 1
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 3
# Episode 21, Action 3
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 1
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 3
# Episode 21, Action 3
# Episode 21, Action 2
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 3
# Episode 21, Action 3
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 0
# Episode 21, Action 1
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 3
# Episode 21, Action 3
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 1
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 1
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 0
# Episode 21, Action 3
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 3
# Episode 21, Action 2
# Episode 21, Action 0
# Episode 21, Action 2
# Episode 21, Action 3
# Episode 21, Action 1
# Episode 21, Action 3
# Episode 21, Action 1
# Episode: 21  Total reward: 0.00  Explore rate: 0.896
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 0
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 3
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 0
# Episode 22, Action 1
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 2
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 3
# Episode 22, Action 3
# Episode 22, Action 2
# Episode 22, Action 2
# Episode 22, Action 3
# Episode 22, Action 3
# Episode 22, Action 2
# Episode 22, Action 2
# Episode 22, Action 3
# Episode 22, Action 3
# Episode 22, Action 0
# Episode 22, Action 3
# Episode 22, Action 3
# Episode 22, Action 0
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 2
# Episode 22, Action 3
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 0
# Episode 22, Action 1
# Episode 22, Action 3
# Episode 22, Action 1
# Episode 22, Action 1
# Episode 22, Action 2
# Episode 22, Action 3
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 1
# Episode 22, Action 3
# Episode 22, Action 0
# Episode 22, Action 3
# Episode 22, Action 1
# Episode 22, Action 3
# Episode 22, Action 0
# Episode 22, Action 1
# Episode 22, Action 0
# Episode 22, Action 2
# Episode 22, Action 1
# Episode 22, Action 1
# Episode 22, Action 0
# Episode 22, Action 3
# Episode 22, Action 2
# Episode 22, Action 0
# Episode 22, Action 1
# ...
# Episode 121, Action 2
# Episode 121, Action 0
# Episode 121, Action 2
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 0
# Episode 121, Action 2
# Episode 121, Action 0
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 0
# Episode 121, Action 2
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 0
# Episode 121, Action 2
# Episode 121, Action 3
# Episode 121, Action 3
# Episode 121, Action 2
# Episode 121, Action 1
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 0
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 1
# Episode 121, Action 2
# Episode 121, Action 3
# Episode 121, Action 0
# Episode 121, Action 3
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 1
# Episode 121, Action 2
# Episode 121, Action 0
# Episode 121, Action 3
# Episode 121, Action 2
# Episode 121, Action 0
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 1
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 3
# Episode 121, Action 2
# Episode 121, Action 1
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 0
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 2
# Episode 121, Action 0
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 2
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 0
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 3
# Episode 121, Action 1
# Episode 121, Action 2
# Episode 121, Action 1
# Episode 121, Action 2
# Episode 121, Action 3
# Episode 121, Action 3
# Episode: 121  Total reward: 1500.00  Explore rate: 0.543
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 0
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 2
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 3
# Episode 122, Action 0
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 2
# Episode 122, Action 3
# Episode 122, Action 0
# Episode 122, Action 2
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 0
# Episode 122, Action 2
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 0
# Episode 122, Action 2
# Episode 122, Action 0
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 0
# Episode 122, Action 3
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 2
# Episode 122, Action 3
# Episode 122, Action 2
# Episode 122, Action 2
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 0
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 2
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 0
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 0
# Episode 122, Action 0
# Episode 122, Action 2
# Episode 122, Action 3
# Episode 122, Action 1
# Episode 122, Action 2
# Episode 122, Action 1
# Episode 122, Action 3
# Episode 122, Action 0
# Episode 122, Action 2
# Episode 122, Action 3
# Episode 122, Action 0
# Episode: 122  Total reward: 1500.00  Explore rate: 0.540
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 1
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 2
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 0
# Episode 123, Action 2
# Episode 123, Action 1
# Episode 123, Action 2
# Episode 123, Action 2
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 1
# Episode 123, Action 3
# Episode 123, Action 0
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 0
# Episode 123, Action 1
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 2
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 2
# Episode 123, Action 1
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 0
# Episode 123, Action 2
# Episode 123, Action 3
# Episode 123, Action 0
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 2
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 2
# Episode 123, Action 3
# Episode 123, Action 2
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 2
# Episode 123, Action 2
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 0
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 1
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 0
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 3
# Episode 123, Action 3
# Episode 123, Action 2
# Episode 123, Action 0
# Episode 123, Action 0
# Episode 123, Action 2
# Episode 123, Action 1
# Episode 123, Action 3
# Episode 123, Action 1
# Episode 123, Action 1
# Episode 123, Action 0
# Episode 123, Action 1
# Episode: 123  Total reward: 1500.00  Explore rate: 0.537
# Episode 124, Action 1
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 2
# Episode 124, Action 0
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 0
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 2
# Episode 124, Action 0
# Episode 124, Action 2
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 3
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 1
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 3
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 3
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 1
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 3
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 2
# Episode 124, Action 2
# Episode 124, Action 1
# Episode 124, Action 2
# Episode 124, Action 0
# Episode 124, Action 3
# Episode 124, Action 2
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 0
# Episode 124, Action 2
# Episode 124, Action 2
# Episode: 124  Total reward: 1500.00  Explore rate: 0.534
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 2
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 0
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 2
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 2
# Episode 125, Action 2
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 0
# Episode 125, Action 2
# Episode 125, Action 3
# Episode 125, Action 2
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 0
# Episode 125, Action 0
# Episode 125, Action 0
# Episode 125, Action 2
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 1
# Episode 125, Action 0
# Episode 125, Action 1
# Episode 125, Action 2
# Episode 125, Action 3
# Episode 125, Action 3
# Episode 125, Action 1
# Episode: 125  Total reward: 1500.00  Explore rate: 0.532
# Episode 126, Action 0
# Episode 126, Action 1
# Episode 126, Action 2
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 0
# Episode 126, Action 0
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 0
# Episode 126, Action 0
# Episode 126, Action 0
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 0
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 3
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 0
# Episode 126, Action 1
# Episode 126, Action 2
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 3
# Episode 126, Action 3
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 3
# Episode 126, Action 0
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 1
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 0
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 0
# Episode 126, Action 2
# Episode 126, Action 1
# Episode 126, Action 0
# Episode 126, Action 2
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 2
# Episode 126, Action 0
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 1
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 0
# Episode 126, Action 2
# Episode 126, Action 3
# Episode 126, Action 1
# Episode 126, Action 0
# Episode: 126  Total reward: 1500.00  Explore rate: 0.529
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 1
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 3
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 3
# Episode 127, Action 2
# Episode 127, Action 3
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 1
# Episode 127, Action 1
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 1
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 3
# Episode 127, Action 3
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 1
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 1
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 1
# Episode 127, Action 3
# Episode 127, Action 0
# Episode 127, Action 3
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 1
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 1
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 1
# Episode 127, Action 3
# Episode 127, Action 3
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 3
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 0
# Episode 127, Action 3
# Episode 127, Action 1
# Episode 127, Action 2
# Episode 127, Action 2
# Episode 127, Action 0
# Episode 127, Action 0
# Episode 127, Action 2
# Episode 127, Action 3
# Episode 127, Action 0
# Episode: 127  Total reward: 1500.00  Explore rate: 0.526
# Training complete!
# Final Q-table sample:
# [[-7.25911239e-07 -2.22117103e-07  5.36226165e-07  1.93292699e-07]
#  [-8.55259754e-07  1.42699529e-06  5.61487050e-07 -1.43165749e-07]
#  [-1.11011269e-06  4.96258105e-07  8.52214125e-07  4.10359600e-07]
#  [-2.77748305e-07 -1.47815661e-07  8.07751979e-07  1.04907491e+00]
#  [ 1.04907463e+00  5.66773456e-07  5.22791418e+00  2.50400461e+00]]
# Number of successful episodes: 0 out of 128
# Last successful episode: 0
# Total reward over all episodes: 1500

# %%
print(f"Total reward after training: {total_reward}, total Explore rate after training: {explore_rate}")
# Out:
# Total reward after training: 1500, total Explore rate after training: 0.5264466124450268

# %% [markdown]
# ## 🐥 Let's see this in action

# %%
# now we show one episode
# yellow spot should be able to find black spot here

tmp_env.manual_mode = True # enable messages
STEP_SIZE_TEST_test = 16

observation = tmp_env.reset()
state_0 = tmp_env.get_1d_state()
total_reward = 0

for _ in range(STEP_SIZE_TEST_test):
    tmp_env.render()
    action = update_action(tmp_env, state_0, explore_rate, Q=Q_test)
    obv, reward, done, info = tmp_env.step(action)
    state_1 = tmp_env.get_1d_state()

    # No need to update the Q here
    state_0 = state_1

    total_reward += reward

print(f"Total_reward: ", total_reward)
# Out:
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Green Land class area
# Next step towards:
# Central Source Secret Location
# Next step towards:
# Green Land class area
# Next step towards:
# Central Source Secret Location
# Next step towards:
# Green Land class area
# Next step towards:
# Central Source Secret Location
# Next step towards:
# Green Land class area
# Next step towards:
# Central Source Secret Location
# Next step towards:
# Green Land class area
# Total_reward:  1200

# %%
# the shape of Q table (Q_test)
print(Q_test.shape)
print(f"Obs space dimensions :{tmp_env.observation_space.shape}")
# Out:
# (144, 4)
# Obs space dimensions :(12, 12)

# %%
# print Q_table in "observation space" light
Q_test.argmax(axis=1).reshape(tmp_env.observation_space.shape)
# Out:
# array([[2, 1, 2, 3, 2, 2, 2, 2, 1, 1, 1, 2],
#        [1, 0, 3, 3, 2, 2, 2, 2, 1, 1, 2, 2],
#        [3, 0, 2, 2, 2, 3, 2, 1, 2, 2, 1, 2],
#        [0, 3, 3, 3, 2, 2, 2, 2, 2, 2, 1, 1],
#        [2, 0, 3, 3, 3, 3, 2, 1, 1, 1, 1, 1],
#        [3, 3, 3, 3, 3, 3, 3, 1, 1, 1, 1, 1],
#        [3, 0, 0, 0, 3, 3, 0, 0, 1, 1, 1, 1],
#        [3, 0, 3, 3, 0, 3, 0, 1, 1, 1, 1, 1],
#        [3, 2, 3, 3, 3, 3, 0, 0, 1, 1, 1, 0],
#        [1, 3, 3, 0, 3, 0, 0, 0, 0, 0, 1, 1],
#        [0, 3, 2, 0, 3, 0, 0, 0, 0, 0, 0, 1],
#        [3, 3, 3, 3, 3, 0, 0, 0, 0, 0, 0, 1]])

# %%
# close the environment
tmp_env.close()
# Out:
# image has more than 3 channels, only first 3 channels are used there are (12, 12, 4) channels

# %% [markdown]
# # 2️⃣ Assignment 2: Trondheim treasure hunt!

# %% [markdown]
# # 🐔 You are ready for the Trondheim challenge now 💪
#
# *   Task 1: Initialize Q table
# *   Task 2: Write necessary helper functions for Q-learning
# *   Task 3: Play with Hyperparameters
# *   Task 4: Train the agent using Q-learning
#
#
# ## **Important Note**:
# For Task 2, Task 3 and Task 4, you can (re)use the same code as in the Assignment 1.
# **These are mentioned here as the elements of the pipeline.**
#
# Most of the code from Assigment 1 is reusable, we are just using it with different environment here.

# %%
# First and important - cleanup!
tmp_env.close()
# Out:
# image has more than 3 channels, only first 3 channels are used there are (12, 12, 4) channels

# %%
# let's configure the environment and see how it looks like
env_config = {
    'env_image_path':'input_images/image_TRD_2.png',
    'dead_allowed':False,
    'remove_after_location_found':True,
    'start_random':False,
    'number_removable_locations':1,
}

if not os.path.exists(env_config['env_image_path']):
  # make sure you have the folder and the image
  print(f"Error: The image path {env_config['env_image_path']} does not exist.")
else:
  # if everything fine, we create the environment
  tmp_env = TrondheimEnv(conf=env_config)
  print(f"Environment successfully created")
# Out:
# Environment successfully created

# %%
tmp_env.reset()
tmp_env.render()
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0,   0, 255],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        ...,
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], shape=(32, 32, 3), dtype=uint8)

# %%
# select the action here
my_action = 'right'

# here is your action
obs, rew, term, info = tmp_env.step(action_dict[my_action])
#print(rew)
tmp_env.render()
# Out:
# Next step towards:
# Green Land class area
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0,   0, 255],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        ...,
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], shape=(32, 32, 3), dtype=uint8)

# %% [markdown]
# ### Task 1: Initialize Q table

# %%
# Task 1: Initialize Q table
"""
TODO: given the environment, initialize the Q table
"""

h, w = tmp_env.observation.shape
n_states = h * w * (tmp_env.number_removable_locations + 1)

n_actions = tmp_env.action_space.n 

Q_table = np.zeros((n_states, n_actions))

# Tip: pay attention to the dimensions of Q table
# Tip: how many states does the table have, how many actions

print(f"Observation space dimensions:  {tmp_env.observation_space.shape}")
print(f"Number of possible actions: {tmp_env.action_space.n}")

# YOUR CODE GOES HERE
Q_test = np.zeros((n_states,n_actions)) # you need to initialize this variable
# Create some noise to the Q-table for breaking ties
Q_test += 1e-6 * np.random.randn(*Q_test.shape)

#print(Q_test.shape)
# Out:
# Observation space dimensions:  (32, 32)
# Number of possible actions: 4

# %% [markdown]
# ### Task 2: Write necessary helper functions for Q-learning

# %%
# Task 2: Write necessary helper functions for Q-learning
# Tip: just use the same helper functions you already implemented above


decay_factor = 0.995
start_explore_rate = 0.995  
start_learning_rate = 0.7

# Explore Rate Decay Function, Converges to MIN_EXPLORE_RATE
def update_explore_rate(episode, MIN_EXPLORE_RATE):
    # this function should return updated explore_rate
	# YOUR CODE GOES HERE    
  explore_rate = max(MIN_EXPLORE_RATE, start_explore_rate * (decay_factor ** episode))
  return explore_rate

# Learning Rate Decay Function, Converges to MIN_LEARNING_RATE
def update_learning_rate(episode, MIN_LEARNING_RATE):
    # this function should return updated learning_rate
	# YOUR CODE GOES HERE
    learning_rate = max(MIN_LEARNING_RATE, start_learning_rate * (decay_factor ** episode))
    return learning_rate

# returns an action based on current state, explore rate and Q table
def update_action(env, state, explore_rate, Q):

    # If a random number between 0 and 1 is less than explore_rate,
    # we explore, else we exploit
    if random.uniform(0, 1) < explore_rate:
        action = env.action_space.sample()
    else:
        action = np.argmax(Q[state, :])
    return action

# YOU DON'T NEED TO DO ANYTHING HERE. They are the same

# %% [markdown]
# ### Task 3: Play with Hyperparameters

# %%
# Task 3: Play with Hyperparameters
# Tip - you can also use the same parameters as for the toy example above
# YOUR CODE GOES HERE (set the values below)
GAMMA_test = 0.5
NUM_EPISODES_test = 2000
MIN_EXPLORE_RATE_test = 0.1
MIN_LEARNING_RATE_test = 0.2
STEP_SIZE_TEST = 0.1
MAX_STEPS_PER_EPISODE = 100

# Helper function to select action with random tie-breaking
def argmax_random(qrow):
    m = np.max(qrow)
    idx = np.flatnonzero(qrow == m)
    return np.random.choice(idx)

# Depending on your parameters for the toy environment, using the same parameters here could work fine
# if they are not working, you may want to set them to different values here

# %% [markdown]
# ## Now use Q-learning to learn the Q table
# ### Task 4: Train the agent using Q-learning

# %%
# Task 4: Train the agent using Q-learning
# Suggestion: you can wrap the code to learn Q-table in a function,
# which you can also use for Task 4 in Assignment 2

# result of the training is:
#   updated Q table (Q_test)
#   total_reward
#   you are free to add others, if you will

tmp_env.manual_mode = False


# initialize some variables
total_reward = 0

explore_rate = update_explore_rate(0, MIN_EXPLORE_RATE=MIN_EXPLORE_RATE_test)
learning_rate = update_learning_rate(0, MIN_LEARNING_RATE=MIN_LEARNING_RATE_test)

rewards_per_episode = []
succesfull_episodes = 0
last_successcful_episode = 0
last_episode_frames = []
halfway_frames = []
# Training loop
for episode in range(NUM_EPISODES_test):
    # reset environment at start of each episode
    obs = tmp_env.reset()
    # get initial state as 1D
    state = tmp_env.get_1d_state()
    # reset total reward for this episode
    reward = 0

    # Update explore rate and learning rate each episode
    explore_rate = update_explore_rate(episode, MIN_EXPLORE_RATE_test)
    learning_rate = update_learning_rate(episode, MIN_LEARNING_RATE_test)
    episode_reward = 0
    # Step through the environment for a number of steps
    for step in range(MAX_STEPS_PER_EPISODE):  # limit number of steps per episode
        # select action based on current state, explore rate and Q table
        action = update_action(tmp_env, state, explore_rate, Q_test)
        #print(f"Episode {episode}, Action {action}")
        # take action and observe next state and reward
        next_obs, reward, terminated, info = tmp_env.step(action)
        # get next state as 1D
        next_state = tmp_env.get_1d_state()

        # Enable rendering for the last episode (prints frames as well...)
        """if episode == NUM_EPISODES_test - 1:
            img = tmp_env.render()
            if step % 5 == 0:
                last_episode_frames.append(img)
        """

        """if episode == NUM_EPISODES_test/2: 
            img = tmp_env.render()
            if step % 5 == 0:
                halfway_frames.append(img)
        """

        # Check if terminated, if so, break
        if terminated:
            succesfull_episodes += 1
            last_successcful_episode = episode
            print(f"Episode {episode} reached the final location!")
            td_target = reward
            Q_test[state, action] += learning_rate * (
            reward + GAMMA_test * Q_test[next_state, best_next_action] - Q_test[state, action]
            ) 
            total_reward += reward
            break

        else:
        # Evaluate best next action from next state
            best_next_action = argmax_random(Q_test[next_state, :])
            td_target = reward + GAMMA_test * Q_test[next_state, best_next_action]
        # update total reward
        Q_test[state, action] += learning_rate * (
            reward + GAMMA_test * Q_test[next_state, best_next_action] - Q_test[state, action]
        )
        episode_reward += reward
        state = next_state

total_reward += episode_reward
    #total_reward += episode_reward
    #rewards_per_episode.append(total_reward)
    #print(f"Episode: {episode}  Total reward: {total_reward:.2f}  Explore rate: {explore_rate:.3f}")

print("Training complete!")
print("Final Q-table sample:")
print(Q_test[:5])
print(f"Number of successful episodes: {succesfull_episodes} out of {NUM_EPISODES_test}")
print(f"Last successful episode: {last_successcful_episode}")
print(f"Total reward over all episodes: {total_reward}")
# Tip: iterate over number of episodes

    # Tip: iterate over number of steps in each Episode
    # Tip: use helper functions defined above to navigate the environment

        # Tip: use the Q-learning update rule equation - Bellman equation



  # Tip : print variables of interest, like episode, total_reward, explore_rate
  # print(f"Episode :{i}  Total_reward: {total_reward}  Explore rate: {explore_rate}")
  #print("Final Q values: ", Q_test)
# Out:
# Episode 192 reached the final location!
# Episode 326 reached the final location!
# Episode 338 reached the final location!
# Episode 394 reached the final location!
# Episode 399 reached the final location!
# Episode 405 reached the final location!
# Episode 411 reached the final location!
# Episode 419 reached the final location!
# Episode 426 reached the final location!
# Episode 432 reached the final location!
# Episode 433 reached the final location!
# Episode 435 reached the final location!
# Episode 447 reached the final location!
# Episode 449 reached the final location!
# Episode 450 reached the final location!
# Episode 452 reached the final location!
# Episode 456 reached the final location!
# Episode 457 reached the final location!
# Episode 459 reached the final location!
# Episode 461 reached the final location!
# Episode 466 reached the final location!
# Episode 468 reached the final location!
# Episode 469 reached the final location!
# Episode 471 reached the final location!
# Episode 473 reached the final location!
# Episode 474 reached the final location!
# Episode 475 reached the final location!
# Episode 476 reached the final location!
# Episode 477 reached the final location!
# Episode 478 reached the final location!
# Episode 479 reached the final location!
# Episode 481 reached the final location!
# Episode 482 reached the final location!
# Episode 483 reached the final location!
# Episode 484 reached the final location!
# Episode 485 reached the final location!
# Episode 486 reached the final location!
# Episode 487 reached the final location!
# Episode 488 reached the final location!
# Episode 489 reached the final location!
# Episode 490 reached the final location!
# Episode 491 reached the final location!
# Episode 492 reached the final location!
# Episode 493 reached the final location!
# Episode 494 reached the final location!
# Episode 495 reached the final location!
# Episode 496 reached the final location!
# Episode 497 reached the final location!
# Episode 498 reached the final location!
# Episode 499 reached the final location!
# Episode 500 reached the final location!
# Episode 502 reached the final location!
# Episode 503 reached the final location!
# Episode 504 reached the final location!
# Episode 505 reached the final location!
# Episode 506 reached the final location!
# Episode 507 reached the final location!
# Episode 508 reached the final location!
# Episode 509 reached the final location!
# Episode 510 reached the final location!
# Episode 511 reached the final location!
# Episode 512 reached the final location!
# Episode 513 reached the final location!
# Episode 514 reached the final location!
# Episode 515 reached the final location!
# Episode 516 reached the final location!
# Episode 517 reached the final location!
# Episode 518 reached the final location!
# Episode 520 reached the final location!
# Episode 521 reached the final location!
# Episode 523 reached the final location!
# Episode 524 reached the final location!
# Episode 525 reached the final location!
# Episode 526 reached the final location!
# Episode 527 reached the final location!
# Episode 528 reached the final location!
# Episode 529 reached the final location!
# Episode 530 reached the final location!
# Episode 531 reached the final location!
# Episode 532 reached the final location!
# Episode 533 reached the final location!
# Episode 534 reached the final location!
# Episode 535 reached the final location!
# Episode 537 reached the final location!
# Episode 538 reached the final location!
# Episode 539 reached the final location!
# Episode 540 reached the final location!
# Episode 541 reached the final location!
# Episode 542 reached the final location!
# Episode 543 reached the final location!
# Episode 544 reached the final location!
# Episode 545 reached the final location!
# Episode 546 reached the final location!
# Episode 547 reached the final location!
# Episode 548 reached the final location!
# Episode 549 reached the final location!
# Episode 550 reached the final location!
# Episode 551 reached the final location!
# Episode 552 reached the final location!
# Episode 553 reached the final location!
# Episode 554 reached the final location!
# Episode 555 reached the final location!
# Episode 556 reached the final location!
# Episode 557 reached the final location!
# Episode 558 reached the final location!
# Episode 559 reached the final location!
# Episode 560 reached the final location!
# Episode 561 reached the final location!
# Episode 562 reached the final location!
# Episode 563 reached the final location!
# Episode 564 reached the final location!
# Episode 565 reached the final location!
# Episode 566 reached the final location!
# Episode 567 reached the final location!
# Episode 568 reached the final location!
# Episode 569 reached the final location!
# Episode 570 reached the final location!
# Episode 571 reached the final location!
# Episode 572 reached the final location!
# Episode 573 reached the final location!
# Episode 574 reached the final location!
# Episode 575 reached the final location!
# Episode 576 reached the final location!
# Episode 577 reached the final location!
# Episode 578 reached the final location!
# Episode 579 reached the final location!
# Episode 580 reached the final location!
# Episode 581 reached the final location!
# Episode 582 reached the final location!
# Episode 583 reached the final location!
# Episode 584 reached the final location!
# Episode 585 reached the final location!
# Episode 586 reached the final location!
# Episode 587 reached the final location!
# Episode 588 reached the final location!
# Episode 589 reached the final location!
# Episode 590 reached the final location!
# Episode 591 reached the final location!
# Episode 592 reached the final location!
# Episode 593 reached the final location!
# Episode 594 reached the final location!
# Episode 595 reached the final location!
# Episode 596 reached the final location!
# Episode 598 reached the final location!
# Episode 599 reached the final location!
# Episode 600 reached the final location!
# Episode 601 reached the final location!
# Episode 602 reached the final location!
# Episode 603 reached the final location!
# Episode 604 reached the final location!
# Episode 605 reached the final location!
# Episode 606 reached the final location!
# Episode 607 reached the final location!
# Episode 608 reached the final location!
# Episode 609 reached the final location!
# Episode 610 reached the final location!
# Episode 611 reached the final location!
# Episode 612 reached the final location!
# Episode 613 reached the final location!
# Episode 614 reached the final location!
# Episode 615 reached the final location!
# Episode 616 reached the final location!
# Episode 617 reached the final location!
# Episode 618 reached the final location!
# Episode 619 reached the final location!
# Episode 620 reached the final location!
# Episode 621 reached the final location!
# Episode 622 reached the final location!
# Episode 623 reached the final location!
# Episode 624 reached the final location!
# Episode 625 reached the final location!
# Episode 626 reached the final location!
# Episode 627 reached the final location!
# Episode 628 reached the final location!
# Episode 629 reached the final location!
# Episode 630 reached the final location!
# Episode 631 reached the final location!
# Episode 632 reached the final location!
# Episode 633 reached the final location!
# Episode 634 reached the final location!
# Episode 635 reached the final location!
# Episode 636 reached the final location!
# Episode 637 reached the final location!
# Episode 638 reached the final location!
# Episode 639 reached the final location!
# Episode 640 reached the final location!
# Episode 641 reached the final location!
# Episode 642 reached the final location!
# Episode 643 reached the final location!
# Episode 644 reached the final location!
# Episode 645 reached the final location!
# Episode 646 reached the final location!
# Episode 647 reached the final location!
# Episode 648 reached the final location!
# Episode 649 reached the final location!
# Episode 650 reached the final location!
# Episode 651 reached the final location!
# Episode 652 reached the final location!
# Episode 653 reached the final location!
# Episode 654 reached the final location!
# Episode 655 reached the final location!
# Episode 656 reached the final location!
# Episode 657 reached the final location!
# Episode 658 reached the final location!
# Episode 659 reached the final location!
# Episode 660 reached the final location!
# Episode 661 reached the final location!
# Episode 662 reached the final location!
# Episode 663 reached the final location!
# Episode 664 reached the final location!
# Episode 665 reached the final location!
# Episode 666 reached the final location!
# Episode 667 reached the final location!
# Episode 668 reached the final location!
# Episode 669 reached the final location!
# Episode 670 reached the final location!
# Episode 671 reached the final location!
# Episode 672 reached the final location!
# Episode 673 reached the final location!
# Episode 674 reached the final location!
# Episode 675 reached the final location!
# Episode 676 reached the final location!
# Episode 677 reached the final location!
# Episode 678 reached the final location!
# Episode 679 reached the final location!
# Episode 680 reached the final location!
# Episode 681 reached the final location!
# Episode 682 reached the final location!
# Episode 683 reached the final location!
# Episode 684 reached the final location!
# Episode 685 reached the final location!
# Episode 686 reached the final location!
# Episode 687 reached the final location!
# Episode 688 reached the final location!
# Episode 689 reached the final location!
# Episode 690 reached the final location!
# Episode 691 reached the final location!
# Episode 692 reached the final location!
# Episode 693 reached the final location!
# Episode 694 reached the final location!
# Episode 695 reached the final location!
# Episode 696 reached the final location!
# Episode 697 reached the final location!
# Episode 698 reached the final location!
# Episode 699 reached the final location!
# Episode 700 reached the final location!
# Episode 701 reached the final location!
# Episode 702 reached the final location!
# Episode 703 reached the final location!
# Episode 704 reached the final location!
# Episode 705 reached the final location!
# Episode 706 reached the final location!
# Episode 707 reached the final location!
# Episode 708 reached the final location!
# Episode 709 reached the final location!
# Episode 710 reached the final location!
# Episode 711 reached the final location!
# Episode 712 reached the final location!
# Episode 713 reached the final location!
# Episode 714 reached the final location!
# Episode 715 reached the final location!
# Episode 716 reached the final location!
# Episode 717 reached the final location!
# Episode 718 reached the final location!
# Episode 719 reached the final location!
# Episode 720 reached the final location!
# Episode 721 reached the final location!
# Episode 722 reached the final location!
# Episode 723 reached the final location!
# Episode 724 reached the final location!
# Episode 725 reached the final location!
# Episode 726 reached the final location!
# Episode 727 reached the final location!
# Episode 728 reached the final location!
# Episode 729 reached the final location!
# Episode 730 reached the final location!
# Episode 731 reached the final location!
# Episode 732 reached the final location!
# Episode 733 reached the final location!
# Episode 734 reached the final location!
# Episode 735 reached the final location!
# Episode 736 reached the final location!
# Episode 737 reached the final location!
# Episode 738 reached the final location!
# Episode 739 reached the final location!
# Episode 740 reached the final location!
# Episode 741 reached the final location!
# Episode 742 reached the final location!
# Episode 743 reached the final location!
# Episode 744 reached the final location!
# Episode 745 reached the final location!
# Episode 746 reached the final location!
# Episode 747 reached the final location!
# Episode 748 reached the final location!
# Episode 749 reached the final location!
# Episode 750 reached the final location!
# Episode 751 reached the final location!
# Episode 752 reached the final location!
# Episode 753 reached the final location!
# Episode 754 reached the final location!
# Episode 755 reached the final location!
# Episode 756 reached the final location!
# Episode 757 reached the final location!
# Episode 758 reached the final location!
# Episode 759 reached the final location!
# Episode 760 reached the final location!
# Episode 761 reached the final location!
# Episode 762 reached the final location!
# Episode 763 reached the final location!
# Episode 764 reached the final location!
# Episode 765 reached the final location!
# Episode 766 reached the final location!
# Episode 767 reached the final location!
# Episode 768 reached the final location!
# Episode 769 reached the final location!
# Episode 770 reached the final location!
# Episode 771 reached the final location!
# Episode 772 reached the final location!
# Episode 773 reached the final location!
# Episode 774 reached the final location!
# Episode 775 reached the final location!
# Episode 776 reached the final location!
# Episode 777 reached the final location!
# Episode 778 reached the final location!
# Episode 779 reached the final location!
# Episode 780 reached the final location!
# Episode 781 reached the final location!
# Episode 782 reached the final location!
# Episode 783 reached the final location!
# Episode 784 reached the final location!
# Episode 785 reached the final location!
# Episode 786 reached the final location!
# Episode 787 reached the final location!
# Episode 788 reached the final location!
# Episode 789 reached the final location!
# Episode 790 reached the final location!
# Episode 791 reached the final location!
# Episode 792 reached the final location!
# Episode 793 reached the final location!
# Episode 794 reached the final location!
# Episode 795 reached the final location!
# Episode 796 reached the final location!
# Episode 797 reached the final location!
# Episode 798 reached the final location!
# Episode 799 reached the final location!
# Episode 800 reached the final location!
# Episode 801 reached the final location!
# Episode 802 reached the final location!
# Episode 803 reached the final location!
# Episode 804 reached the final location!
# Episode 805 reached the final location!
# Episode 806 reached the final location!
# Episode 807 reached the final location!
# Episode 808 reached the final location!
# Episode 809 reached the final location!
# Episode 810 reached the final location!
# Episode 811 reached the final location!
# Episode 812 reached the final location!
# Episode 813 reached the final location!
# Episode 814 reached the final location!
# Episode 815 reached the final location!
# Episode 816 reached the final location!
# Episode 817 reached the final location!
# Episode 818 reached the final location!
# Episode 819 reached the final location!
# Episode 820 reached the final location!
# Episode 821 reached the final location!
# Episode 822 reached the final location!
# Episode 823 reached the final location!
# Episode 824 reached the final location!
# Episode 825 reached the final location!
# Episode 826 reached the final location!
# Episode 827 reached the final location!
# Episode 828 reached the final location!
# Episode 829 reached the final location!
# Episode 830 reached the final location!
# Episode 831 reached the final location!
# Episode 832 reached the final location!
# Episode 834 reached the final location!
# Episode 835 reached the final location!
# Episode 836 reached the final location!
# Episode 837 reached the final location!
# Episode 838 reached the final location!
# Episode 839 reached the final location!
# Episode 840 reached the final location!
# Episode 841 reached the final location!
# Episode 842 reached the final location!
# Episode 843 reached the final location!
# Episode 844 reached the final location!
# Episode 845 reached the final location!
# Episode 846 reached the final location!
# Episode 847 reached the final location!
# Episode 848 reached the final location!
# Episode 849 reached the final location!
# Episode 850 reached the final location!
# Episode 851 reached the final location!
# Episode 853 reached the final location!
# Episode 854 reached the final location!
# Episode 855 reached the final location!
# Episode 856 reached the final location!
# Episode 857 reached the final location!
# Episode 858 reached the final location!
# Episode 859 reached the final location!
# Episode 860 reached the final location!
# Episode 861 reached the final location!
# Episode 862 reached the final location!
# Episode 863 reached the final location!
# Episode 864 reached the final location!
# Episode 865 reached the final location!
# Episode 866 reached the final location!
# Episode 867 reached the final location!
# Episode 868 reached the final location!
# Episode 869 reached the final location!
# Episode 870 reached the final location!
# Episode 871 reached the final location!
# Episode 872 reached the final location!
# Episode 873 reached the final location!
# Episode 874 reached the final location!
# Episode 875 reached the final location!
# Episode 876 reached the final location!
# Episode 877 reached the final location!
# Episode 878 reached the final location!
# Episode 879 reached the final location!
# Episode 880 reached the final location!
# Episode 881 reached the final location!
# Episode 882 reached the final location!
# Episode 883 reached the final location!
# Episode 884 reached the final location!
# Episode 885 reached the final location!
# Episode 886 reached the final location!
# Episode 887 reached the final location!
# Episode 888 reached the final location!
# Episode 889 reached the final location!
# Episode 890 reached the final location!
# Episode 891 reached the final location!
# Episode 892 reached the final location!
# Episode 893 reached the final location!
# Episode 894 reached the final location!
# Episode 895 reached the final location!
# Episode 896 reached the final location!
# Episode 897 reached the final location!
# Episode 898 reached the final location!
# Episode 899 reached the final location!
# Episode 900 reached the final location!
# Episode 901 reached the final location!
# Episode 902 reached the final location!
# Episode 903 reached the final location!
# Episode 904 reached the final location!
# Episode 905 reached the final location!
# Episode 906 reached the final location!
# Episode 907 reached the final location!
# Episode 908 reached the final location!
# Episode 909 reached the final location!
# Episode 910 reached the final location!
# Episode 911 reached the final location!
# Episode 912 reached the final location!
# Episode 913 reached the final location!
# Episode 914 reached the final location!
# Episode 915 reached the final location!
# Episode 916 reached the final location!
# Episode 918 reached the final location!
# Episode 919 reached the final location!
# Episode 920 reached the final location!
# Episode 921 reached the final location!
# Episode 922 reached the final location!
# Episode 923 reached the final location!
# Episode 924 reached the final location!
# Episode 925 reached the final location!
# Episode 926 reached the final location!
# Episode 927 reached the final location!
# Episode 928 reached the final location!
# Episode 929 reached the final location!
# Episode 930 reached the final location!
# Episode 931 reached the final location!
# Episode 932 reached the final location!
# Episode 933 reached the final location!
# Episode 934 reached the final location!
# Episode 935 reached the final location!
# Episode 936 reached the final location!
# Episode 937 reached the final location!
# Episode 938 reached the final location!
# Episode 939 reached the final location!
# Episode 940 reached the final location!
# Episode 941 reached the final location!
# Episode 942 reached the final location!
# Episode 943 reached the final location!
# Episode 944 reached the final location!
# Episode 945 reached the final location!
# Episode 946 reached the final location!
# Episode 947 reached the final location!
# Episode 948 reached the final location!
# Episode 949 reached the final location!
# Episode 950 reached the final location!
# Episode 951 reached the final location!
# Episode 952 reached the final location!
# Episode 953 reached the final location!
# Episode 954 reached the final location!
# Episode 955 reached the final location!
# Episode 956 reached the final location!
# Episode 957 reached the final location!
# Episode 958 reached the final location!
# Episode 959 reached the final location!
# Episode 960 reached the final location!
# Episode 961 reached the final location!
# Episode 962 reached the final location!
# Episode 963 reached the final location!
# Episode 964 reached the final location!
# Episode 965 reached the final location!
# Episode 966 reached the final location!
# Episode 967 reached the final location!
# Episode 968 reached the final location!
# Episode 969 reached the final location!
# Episode 970 reached the final location!
# Episode 971 reached the final location!
# Episode 972 reached the final location!
# Episode 973 reached the final location!
# Episode 974 reached the final location!
# Episode 975 reached the final location!
# Episode 976 reached the final location!
# Episode 977 reached the final location!
# Episode 978 reached the final location!
# Episode 979 reached the final location!
# Episode 980 reached the final location!
# Episode 981 reached the final location!
# Episode 982 reached the final location!
# Episode 983 reached the final location!
# Episode 984 reached the final location!
# Episode 985 reached the final location!
# Episode 986 reached the final location!
# Episode 987 reached the final location!
# Episode 988 reached the final location!
# Episode 989 reached the final location!
# Episode 990 reached the final location!
# Episode 991 reached the final location!
# Episode 992 reached the final location!
# Episode 993 reached the final location!
# Episode 994 reached the final location!
# Episode 995 reached the final location!
# Episode 996 reached the final location!
# Episode 997 reached the final location!
# Episode 998 reached the final location!
# Episode 999 reached the final location!
# Episode 1000 reached the final location!
# Episode 1001 reached the final location!
# Episode 1002 reached the final location!
# Episode 1003 reached the final location!
# Episode 1004 reached the final location!
# Episode 1005 reached the final location!
# Episode 1006 reached the final location!
# Episode 1007 reached the final location!
# Episode 1008 reached the final location!
# Episode 1009 reached the final location!
# Episode 1010 reached the final location!
# Episode 1011 reached the final location!
# Episode 1012 reached the final location!
# Episode 1013 reached the final location!
# Episode 1014 reached the final location!
# Episode 1015 reached the final location!
# Episode 1016 reached the final location!
# Episode 1017 reached the final location!
# Episode 1018 reached the final location!
# Episode 1019 reached the final location!
# Episode 1020 reached the final location!
# Episode 1021 reached the final location!
# Episode 1023 reached the final location!
# Episode 1024 reached the final location!
# Episode 1025 reached the final location!
# Episode 1026 reached the final location!
# Episode 1027 reached the final location!
# Episode 1028 reached the final location!
# Episode 1029 reached the final location!
# Episode 1030 reached the final location!
# Episode 1031 reached the final location!
# Episode 1032 reached the final location!
# Episode 1033 reached the final location!
# Episode 1034 reached the final location!
# Episode 1035 reached the final location!
# Episode 1036 reached the final location!
# Episode 1037 reached the final location!
# Episode 1038 reached the final location!
# Episode 1039 reached the final location!
# Episode 1040 reached the final location!
# Episode 1041 reached the final location!
# Episode 1042 reached the final location!
# Episode 1043 reached the final location!
# Episode 1044 reached the final location!
# Episode 1045 reached the final location!
# Episode 1046 reached the final location!
# Episode 1047 reached the final location!
# Episode 1048 reached the final location!
# Episode 1049 reached the final location!
# Episode 1050 reached the final location!
# Episode 1051 reached the final location!
# Episode 1052 reached the final location!
# Episode 1053 reached the final location!
# Episode 1054 reached the final location!
# Episode 1055 reached the final location!
# Episode 1056 reached the final location!
# Episode 1057 reached the final location!
# Episode 1058 reached the final location!
# Episode 1059 reached the final location!
# Episode 1060 reached the final location!
# Episode 1061 reached the final location!
# Episode 1062 reached the final location!
# Episode 1063 reached the final location!
# Episode 1064 reached the final location!
# Episode 1065 reached the final location!
# Episode 1066 reached the final location!
# Episode 1067 reached the final location!
# Episode 1068 reached the final location!
# Episode 1069 reached the final location!
# Episode 1070 reached the final location!
# Episode 1071 reached the final location!
# Episode 1072 reached the final location!
# Episode 1073 reached the final location!
# Episode 1074 reached the final location!
# Episode 1075 reached the final location!
# Episode 1076 reached the final location!
# Episode 1077 reached the final location!
# Episode 1078 reached the final location!
# Episode 1079 reached the final location!
# Episode 1080 reached the final location!
# Episode 1081 reached the final location!
# Episode 1082 reached the final location!
# Episode 1083 reached the final location!
# Episode 1084 reached the final location!
# Episode 1085 reached the final location!
# Episode 1086 reached the final location!
# Episode 1087 reached the final location!
# Episode 1088 reached the final location!
# Episode 1089 reached the final location!
# Episode 1090 reached the final location!
# Episode 1091 reached the final location!
# Episode 1092 reached the final location!
# Episode 1093 reached the final location!
# Episode 1094 reached the final location!
# Episode 1095 reached the final location!
# Episode 1096 reached the final location!
# Episode 1097 reached the final location!
# Episode 1098 reached the final location!
# Episode 1099 reached the final location!
# Episode 1100 reached the final location!
# Episode 1101 reached the final location!
# Episode 1102 reached the final location!
# Episode 1103 reached the final location!
# Episode 1104 reached the final location!
# Episode 1105 reached the final location!
# Episode 1106 reached the final location!
# Episode 1107 reached the final location!
# Episode 1108 reached the final location!
# Episode 1109 reached the final location!
# Episode 1110 reached the final location!
# Episode 1111 reached the final location!
# Episode 1112 reached the final location!
# Episode 1113 reached the final location!
# Episode 1114 reached the final location!
# Episode 1115 reached the final location!
# Episode 1116 reached the final location!
# Episode 1117 reached the final location!
# Episode 1118 reached the final location!
# Episode 1119 reached the final location!
# Episode 1120 reached the final location!
# Episode 1121 reached the final location!
# Episode 1122 reached the final location!
# Episode 1123 reached the final location!
# Episode 1124 reached the final location!
# Episode 1125 reached the final location!
# Episode 1126 reached the final location!
# Episode 1127 reached the final location!
# Episode 1128 reached the final location!
# Episode 1129 reached the final location!
# Episode 1130 reached the final location!
# Episode 1131 reached the final location!
# Episode 1132 reached the final location!
# Episode 1133 reached the final location!
# Episode 1134 reached the final location!
# Episode 1135 reached the final location!
# Episode 1136 reached the final location!
# Episode 1137 reached the final location!
# Episode 1138 reached the final location!
# Episode 1139 reached the final location!
# Episode 1140 reached the final location!
# Episode 1141 reached the final location!
# Episode 1142 reached the final location!
# Episode 1143 reached the final location!
# Episode 1144 reached the final location!
# Episode 1145 reached the final location!
# Episode 1146 reached the final location!
# Episode 1147 reached the final location!
# Episode 1148 reached the final location!
# Episode 1149 reached the final location!
# Episode 1150 reached the final location!
# Episode 1151 reached the final location!
# Episode 1152 reached the final location!
# Episode 1153 reached the final location!
# Episode 1154 reached the final location!
# Episode 1155 reached the final location!
# Episode 1156 reached the final location!
# Episode 1157 reached the final location!
# Episode 1158 reached the final location!
# Episode 1159 reached the final location!
# Episode 1160 reached the final location!
# Episode 1161 reached the final location!
# Episode 1162 reached the final location!
# Episode 1163 reached the final location!
# Episode 1164 reached the final location!
# Episode 1165 reached the final location!
# Episode 1166 reached the final location!
# Episode 1167 reached the final location!
# Episode 1168 reached the final location!
# Episode 1169 reached the final location!
# Episode 1170 reached the final location!
# Episode 1171 reached the final location!
# Episode 1172 reached the final location!
# Episode 1173 reached the final location!
# Episode 1174 reached the final location!
# Episode 1175 reached the final location!
# Episode 1176 reached the final location!
# Episode 1177 reached the final location!
# Episode 1178 reached the final location!
# Episode 1179 reached the final location!
# Episode 1180 reached the final location!
# Episode 1181 reached the final location!
# Episode 1182 reached the final location!
# Episode 1183 reached the final location!
# Episode 1184 reached the final location!
# Episode 1185 reached the final location!
# Episode 1186 reached the final location!
# Episode 1187 reached the final location!
# Episode 1188 reached the final location!
# Episode 1189 reached the final location!
# Episode 1190 reached the final location!
# Episode 1191 reached the final location!
# Episode 1192 reached the final location!
# Episode 1193 reached the final location!
# Episode 1194 reached the final location!
# Episode 1195 reached the final location!
# Episode 1196 reached the final location!
# Episode 1197 reached the final location!
# Episode 1198 reached the final location!
# Episode 1199 reached the final location!
# Episode 1200 reached the final location!
# Episode 1201 reached the final location!
# Episode 1202 reached the final location!
# Episode 1203 reached the final location!
# Episode 1204 reached the final location!
# Episode 1205 reached the final location!
# Episode 1206 reached the final location!
# Episode 1207 reached the final location!
# Episode 1208 reached the final location!
# Episode 1209 reached the final location!
# Episode 1210 reached the final location!
# Episode 1211 reached the final location!
# Episode 1212 reached the final location!
# Episode 1213 reached the final location!
# Episode 1214 reached the final location!
# Episode 1215 reached the final location!
# Episode 1216 reached the final location!
# Episode 1217 reached the final location!
# Episode 1218 reached the final location!
# Episode 1219 reached the final location!
# Episode 1220 reached the final location!
# Episode 1221 reached the final location!
# Episode 1222 reached the final location!
# Episode 1223 reached the final location!
# Episode 1224 reached the final location!
# Episode 1225 reached the final location!
# Episode 1226 reached the final location!
# Episode 1227 reached the final location!
# Episode 1228 reached the final location!
# Episode 1229 reached the final location!
# Episode 1230 reached the final location!
# Episode 1231 reached the final location!
# Episode 1232 reached the final location!
# Episode 1233 reached the final location!
# Episode 1234 reached the final location!
# Episode 1235 reached the final location!
# Episode 1236 reached the final location!
# Episode 1237 reached the final location!
# Episode 1238 reached the final location!
# Episode 1239 reached the final location!
# Episode 1240 reached the final location!
# Episode 1241 reached the final location!
# Episode 1242 reached the final location!
# Episode 1243 reached the final location!
# Episode 1244 reached the final location!
# Episode 1245 reached the final location!
# Episode 1246 reached the final location!
# Episode 1247 reached the final location!
# Episode 1248 reached the final location!
# Episode 1249 reached the final location!
# Episode 1250 reached the final location!
# Episode 1251 reached the final location!
# Episode 1252 reached the final location!
# Episode 1253 reached the final location!
# Episode 1254 reached the final location!
# Episode 1255 reached the final location!
# Episode 1256 reached the final location!
# Episode 1257 reached the final location!
# Episode 1258 reached the final location!
# Episode 1259 reached the final location!
# Episode 1260 reached the final location!
# Episode 1261 reached the final location!
# Episode 1262 reached the final location!
# Episode 1263 reached the final location!
# Episode 1264 reached the final location!
# Episode 1265 reached the final location!
# Episode 1266 reached the final location!
# Episode 1267 reached the final location!
# Episode 1268 reached the final location!
# Episode 1269 reached the final location!
# Episode 1270 reached the final location!
# Episode 1271 reached the final location!
# Episode 1272 reached the final location!
# Episode 1273 reached the final location!
# Episode 1274 reached the final location!
# Episode 1275 reached the final location!
# Episode 1276 reached the final location!
# Episode 1277 reached the final location!
# Episode 1278 reached the final location!
# Episode 1279 reached the final location!
# Episode 1280 reached the final location!
# Episode 1281 reached the final location!
# Episode 1282 reached the final location!
# Episode 1283 reached the final location!
# Episode 1284 reached the final location!
# Episode 1285 reached the final location!
# Episode 1286 reached the final location!
# Episode 1287 reached the final location!
# Episode 1288 reached the final location!
# Episode 1289 reached the final location!
# Episode 1290 reached the final location!
# Episode 1291 reached the final location!
# Episode 1292 reached the final location!
# Episode 1293 reached the final location!
# Episode 1294 reached the final location!
# Episode 1295 reached the final location!
# Episode 1296 reached the final location!
# Episode 1297 reached the final location!
# Episode 1298 reached the final location!
# Episode 1299 reached the final location!
# Episode 1300 reached the final location!
# Episode 1301 reached the final location!
# Episode 1302 reached the final location!
# Episode 1303 reached the final location!
# Episode 1304 reached the final location!
# Episode 1305 reached the final location!
# Episode 1306 reached the final location!
# Episode 1307 reached the final location!
# Episode 1308 reached the final location!
# Episode 1309 reached the final location!
# Episode 1310 reached the final location!
# Episode 1311 reached the final location!
# Episode 1312 reached the final location!
# Episode 1313 reached the final location!
# Episode 1314 reached the final location!
# Episode 1315 reached the final location!
# Episode 1316 reached the final location!
# Episode 1317 reached the final location!
# Episode 1318 reached the final location!
# Episode 1319 reached the final location!
# Episode 1320 reached the final location!
# Episode 1321 reached the final location!
# Episode 1322 reached the final location!
# Episode 1323 reached the final location!
# Episode 1324 reached the final location!
# Episode 1326 reached the final location!
# Episode 1327 reached the final location!
# Episode 1328 reached the final location!
# Episode 1329 reached the final location!
# Episode 1330 reached the final location!
# Episode 1331 reached the final location!
# Episode 1332 reached the final location!
# Episode 1333 reached the final location!
# Episode 1334 reached the final location!
# Episode 1335 reached the final location!
# Episode 1336 reached the final location!
# Episode 1337 reached the final location!
# Episode 1338 reached the final location!
# Episode 1339 reached the final location!
# Episode 1340 reached the final location!
# Episode 1341 reached the final location!
# Episode 1342 reached the final location!
# Episode 1343 reached the final location!
# Episode 1344 reached the final location!
# Episode 1345 reached the final location!
# Episode 1346 reached the final location!
# Episode 1347 reached the final location!
# Episode 1348 reached the final location!
# Episode 1349 reached the final location!
# Episode 1350 reached the final location!
# Episode 1351 reached the final location!
# Episode 1352 reached the final location!
# Episode 1353 reached the final location!
# Episode 1354 reached the final location!
# Episode 1355 reached the final location!
# Episode 1356 reached the final location!
# Episode 1357 reached the final location!
# Episode 1358 reached the final location!
# Episode 1359 reached the final location!
# Episode 1360 reached the final location!
# Episode 1361 reached the final location!
# Episode 1362 reached the final location!
# Episode 1363 reached the final location!
# Episode 1364 reached the final location!
# Episode 1365 reached the final location!
# Episode 1366 reached the final location!
# Episode 1367 reached the final location!
# Episode 1368 reached the final location!
# Episode 1369 reached the final location!
# Episode 1370 reached the final location!
# Episode 1371 reached the final location!
# Episode 1372 reached the final location!
# Episode 1373 reached the final location!
# Episode 1374 reached the final location!
# Episode 1375 reached the final location!
# Episode 1376 reached the final location!
# Episode 1377 reached the final location!
# Episode 1378 reached the final location!
# Episode 1379 reached the final location!
# Episode 1380 reached the final location!
# Episode 1381 reached the final location!
# Episode 1382 reached the final location!
# Episode 1383 reached the final location!
# Episode 1384 reached the final location!
# Episode 1385 reached the final location!
# Episode 1386 reached the final location!
# Episode 1387 reached the final location!
# Episode 1388 reached the final location!
# Episode 1389 reached the final location!
# Episode 1390 reached the final location!
# Episode 1391 reached the final location!
# Episode 1392 reached the final location!
# Episode 1393 reached the final location!
# Episode 1394 reached the final location!
# Episode 1395 reached the final location!
# Episode 1396 reached the final location!
# Episode 1397 reached the final location!
# Episode 1398 reached the final location!
# Episode 1399 reached the final location!
# Episode 1400 reached the final location!
# Episode 1401 reached the final location!
# Episode 1402 reached the final location!
# Episode 1403 reached the final location!
# Episode 1404 reached the final location!
# Episode 1405 reached the final location!
# Episode 1406 reached the final location!
# Episode 1407 reached the final location!
# Episode 1408 reached the final location!
# Episode 1409 reached the final location!
# Episode 1410 reached the final location!
# Episode 1411 reached the final location!
# Episode 1412 reached the final location!
# Episode 1413 reached the final location!
# Episode 1414 reached the final location!
# Episode 1415 reached the final location!
# Episode 1416 reached the final location!
# Episode 1417 reached the final location!
# Episode 1418 reached the final location!
# Episode 1419 reached the final location!
# Episode 1420 reached the final location!
# Episode 1421 reached the final location!
# Episode 1422 reached the final location!
# Episode 1423 reached the final location!
# Episode 1424 reached the final location!
# Episode 1425 reached the final location!
# Episode 1426 reached the final location!
# Episode 1427 reached the final location!
# Episode 1428 reached the final location!
# Episode 1429 reached the final location!
# Episode 1430 reached the final location!
# Episode 1431 reached the final location!
# Episode 1432 reached the final location!
# Episode 1433 reached the final location!
# Episode 1434 reached the final location!
# Episode 1435 reached the final location!
# Episode 1436 reached the final location!
# Episode 1437 reached the final location!
# Episode 1438 reached the final location!
# Episode 1439 reached the final location!
# Episode 1440 reached the final location!
# Episode 1441 reached the final location!
# Episode 1442 reached the final location!
# Episode 1443 reached the final location!
# Episode 1444 reached the final location!
# Episode 1445 reached the final location!
# Episode 1446 reached the final location!
# Episode 1447 reached the final location!
# Episode 1448 reached the final location!
# Episode 1449 reached the final location!
# Episode 1450 reached the final location!
# Episode 1451 reached the final location!
# Episode 1452 reached the final location!
# Episode 1453 reached the final location!
# Episode 1454 reached the final location!
# Episode 1455 reached the final location!
# Episode 1456 reached the final location!
# Episode 1457 reached the final location!
# Episode 1458 reached the final location!
# Episode 1459 reached the final location!
# Episode 1460 reached the final location!
# Episode 1461 reached the final location!
# Episode 1462 reached the final location!
# Episode 1463 reached the final location!
# Episode 1464 reached the final location!
# Episode 1465 reached the final location!
# Episode 1466 reached the final location!
# Episode 1467 reached the final location!
# Episode 1468 reached the final location!
# Episode 1469 reached the final location!
# Episode 1470 reached the final location!
# Episode 1471 reached the final location!
# Episode 1472 reached the final location!
# Episode 1473 reached the final location!
# Episode 1474 reached the final location!
# Episode 1475 reached the final location!
# Episode 1476 reached the final location!
# Episode 1477 reached the final location!
# Episode 1478 reached the final location!
# Episode 1479 reached the final location!
# Episode 1480 reached the final location!
# Episode 1481 reached the final location!
# Episode 1482 reached the final location!
# Episode 1483 reached the final location!
# Episode 1484 reached the final location!
# Episode 1485 reached the final location!
# Episode 1486 reached the final location!
# Episode 1487 reached the final location!
# Episode 1488 reached the final location!
# Episode 1489 reached the final location!
# Episode 1490 reached the final location!
# Episode 1491 reached the final location!
# Episode 1492 reached the final location!
# Episode 1493 reached the final location!
# Episode 1494 reached the final location!
# Episode 1495 reached the final location!
# Episode 1496 reached the final location!
# Episode 1497 reached the final location!
# Episode 1498 reached the final location!
# Episode 1499 reached the final location!
# Episode 1500 reached the final location!
# Episode 1501 reached the final location!
# Episode 1502 reached the final location!
# Episode 1503 reached the final location!
# Episode 1504 reached the final location!
# Episode 1505 reached the final location!
# Episode 1506 reached the final location!
# Episode 1507 reached the final location!
# Episode 1508 reached the final location!
# Episode 1509 reached the final location!
# Episode 1510 reached the final location!
# Episode 1511 reached the final location!
# Episode 1512 reached the final location!
# Episode 1513 reached the final location!
# Episode 1514 reached the final location!
# Episode 1515 reached the final location!
# Episode 1516 reached the final location!
# Episode 1517 reached the final location!
# Episode 1518 reached the final location!
# Episode 1519 reached the final location!
# Episode 1520 reached the final location!
# Episode 1521 reached the final location!
# Episode 1522 reached the final location!
# Episode 1523 reached the final location!
# Episode 1524 reached the final location!
# Episode 1525 reached the final location!
# Episode 1526 reached the final location!
# Episode 1527 reached the final location!
# Episode 1528 reached the final location!
# Episode 1529 reached the final location!
# Episode 1530 reached the final location!
# Episode 1531 reached the final location!
# Episode 1532 reached the final location!
# Episode 1533 reached the final location!
# Episode 1534 reached the final location!
# Episode 1535 reached the final location!
# Episode 1536 reached the final location!
# Episode 1537 reached the final location!
# Episode 1538 reached the final location!
# Episode 1539 reached the final location!
# Episode 1540 reached the final location!
# Episode 1541 reached the final location!
# Episode 1542 reached the final location!
# Episode 1543 reached the final location!
# Episode 1544 reached the final location!
# Episode 1545 reached the final location!
# Episode 1546 reached the final location!
# Episode 1547 reached the final location!
# Episode 1548 reached the final location!
# Episode 1549 reached the final location!
# Episode 1550 reached the final location!
# Episode 1551 reached the final location!
# Episode 1552 reached the final location!
# Episode 1553 reached the final location!
# Episode 1554 reached the final location!
# Episode 1555 reached the final location!
# Episode 1556 reached the final location!
# Episode 1557 reached the final location!
# Episode 1558 reached the final location!
# Episode 1559 reached the final location!
# Episode 1560 reached the final location!
# Episode 1561 reached the final location!
# Episode 1562 reached the final location!
# Episode 1563 reached the final location!
# Episode 1564 reached the final location!
# Episode 1565 reached the final location!
# Episode 1566 reached the final location!
# Episode 1567 reached the final location!
# Episode 1568 reached the final location!
# Episode 1569 reached the final location!
# Episode 1570 reached the final location!
# Episode 1571 reached the final location!
# Episode 1572 reached the final location!
# Episode 1573 reached the final location!
# Episode 1574 reached the final location!
# Episode 1575 reached the final location!
# Episode 1576 reached the final location!
# Episode 1577 reached the final location!
# Episode 1578 reached the final location!
# Episode 1579 reached the final location!
# Episode 1580 reached the final location!
# Episode 1581 reached the final location!
# Episode 1582 reached the final location!
# Episode 1583 reached the final location!
# Episode 1584 reached the final location!
# Episode 1585 reached the final location!
# Episode 1586 reached the final location!
# Episode 1587 reached the final location!
# Episode 1588 reached the final location!
# Episode 1589 reached the final location!
# Episode 1590 reached the final location!
# Episode 1591 reached the final location!
# Episode 1592 reached the final location!
# Episode 1593 reached the final location!
# Episode 1594 reached the final location!
# Episode 1595 reached the final location!
# Episode 1596 reached the final location!
# Episode 1597 reached the final location!
# Episode 1598 reached the final location!
# Episode 1599 reached the final location!
# Episode 1600 reached the final location!
# Episode 1601 reached the final location!
# Episode 1602 reached the final location!
# Episode 1603 reached the final location!
# Episode 1604 reached the final location!
# Episode 1605 reached the final location!
# Episode 1606 reached the final location!
# Episode 1607 reached the final location!
# Episode 1608 reached the final location!
# Episode 1609 reached the final location!
# Episode 1610 reached the final location!
# Episode 1611 reached the final location!
# Episode 1612 reached the final location!
# Episode 1613 reached the final location!
# Episode 1614 reached the final location!
# Episode 1615 reached the final location!
# Episode 1616 reached the final location!
# Episode 1617 reached the final location!
# Episode 1618 reached the final location!
# Episode 1619 reached the final location!
# Episode 1620 reached the final location!
# Episode 1621 reached the final location!
# Episode 1622 reached the final location!
# Episode 1623 reached the final location!
# Episode 1624 reached the final location!
# Episode 1625 reached the final location!
# Episode 1626 reached the final location!
# Episode 1627 reached the final location!
# Episode 1628 reached the final location!
# Episode 1629 reached the final location!
# Episode 1630 reached the final location!
# Episode 1631 reached the final location!
# Episode 1632 reached the final location!
# Episode 1633 reached the final location!
# Episode 1634 reached the final location!
# Episode 1635 reached the final location!
# Episode 1636 reached the final location!
# Episode 1637 reached the final location!
# Episode 1638 reached the final location!
# Episode 1639 reached the final location!
# Episode 1640 reached the final location!
# Episode 1641 reached the final location!
# Episode 1642 reached the final location!
# Episode 1643 reached the final location!
# Episode 1644 reached the final location!
# Episode 1645 reached the final location!
# Episode 1646 reached the final location!
# Episode 1647 reached the final location!
# Episode 1648 reached the final location!
# Episode 1649 reached the final location!
# Episode 1650 reached the final location!
# Episode 1651 reached the final location!
# Episode 1652 reached the final location!
# Episode 1653 reached the final location!
# Episode 1654 reached the final location!
# Episode 1655 reached the final location!
# Episode 1656 reached the final location!
# Episode 1657 reached the final location!
# Episode 1658 reached the final location!
# Episode 1659 reached the final location!
# Episode 1660 reached the final location!
# Episode 1661 reached the final location!
# Episode 1662 reached the final location!
# Episode 1663 reached the final location!
# Episode 1664 reached the final location!
# Episode 1665 reached the final location!
# Episode 1666 reached the final location!
# Episode 1667 reached the final location!
# Episode 1668 reached the final location!
# Episode 1669 reached the final location!
# Episode 1670 reached the final location!
# Episode 1671 reached the final location!
# Episode 1672 reached the final location!
# Episode 1673 reached the final location!
# Episode 1674 reached the final location!
# Episode 1675 reached the final location!
# Episode 1676 reached the final location!
# Episode 1677 reached the final location!
# Episode 1678 reached the final location!
# Episode 1679 reached the final location!
# Episode 1680 reached the final location!
# Episode 1681 reached the final location!
# Episode 1682 reached the final location!
# Episode 1683 reached the final location!
# Episode 1684 reached the final location!
# Episode 1685 reached the final location!
# Episode 1686 reached the final location!
# Episode 1687 reached the final location!
# Episode 1688 reached the final location!
# Episode 1689 reached the final location!
# Episode 1690 reached the final location!
# Episode 1691 reached the final location!
# Episode 1692 reached the final location!
# Episode 1693 reached the final location!
# Episode 1694 reached the final location!
# Episode 1695 reached the final location!
# Episode 1696 reached the final location!
# Episode 1697 reached the final location!
# Episode 1698 reached the final location!
# Episode 1699 reached the final location!
# Episode 1700 reached the final location!
# Episode 1701 reached the final location!
# Episode 1702 reached the final location!
# Episode 1703 reached the final location!
# Episode 1704 reached the final location!
# Episode 1705 reached the final location!
# Episode 1706 reached the final location!
# Episode 1707 reached the final location!
# Episode 1708 reached the final location!
# Episode 1709 reached the final location!
# Episode 1710 reached the final location!
# Episode 1711 reached the final location!
# Episode 1712 reached the final location!
# Episode 1713 reached the final location!
# Episode 1714 reached the final location!
# Episode 1715 reached the final location!
# Episode 1716 reached the final location!
# Episode 1717 reached the final location!
# Episode 1718 reached the final location!
# Episode 1719 reached the final location!
# Episode 1720 reached the final location!
# Episode 1721 reached the final location!
# Episode 1722 reached the final location!
# Episode 1723 reached the final location!
# Episode 1724 reached the final location!
# Episode 1725 reached the final location!
# Episode 1726 reached the final location!
# Episode 1727 reached the final location!
# Episode 1728 reached the final location!
# Episode 1729 reached the final location!
# Episode 1730 reached the final location!
# Episode 1731 reached the final location!
# Episode 1732 reached the final location!
# Episode 1733 reached the final location!
# Episode 1734 reached the final location!
# Episode 1735 reached the final location!
# Episode 1736 reached the final location!
# Episode 1737 reached the final location!
# Episode 1738 reached the final location!
# Episode 1739 reached the final location!
# Episode 1740 reached the final location!
# Episode 1741 reached the final location!
# Episode 1742 reached the final location!
# Episode 1743 reached the final location!
# Episode 1744 reached the final location!
# Episode 1745 reached the final location!
# Episode 1746 reached the final location!
# Episode 1747 reached the final location!
# Episode 1748 reached the final location!
# Episode 1749 reached the final location!
# Episode 1750 reached the final location!
# Episode 1751 reached the final location!
# Episode 1752 reached the final location!
# Episode 1753 reached the final location!
# Episode 1754 reached the final location!
# Episode 1755 reached the final location!
# Episode 1756 reached the final location!
# Episode 1757 reached the final location!
# Episode 1758 reached the final location!
# Episode 1759 reached the final location!
# Episode 1760 reached the final location!
# Episode 1761 reached the final location!
# Episode 1762 reached the final location!
# Episode 1763 reached the final location!
# Episode 1764 reached the final location!
# Episode 1765 reached the final location!
# Episode 1766 reached the final location!
# Episode 1767 reached the final location!
# Episode 1768 reached the final location!
# Episode 1769 reached the final location!
# Episode 1770 reached the final location!
# Episode 1771 reached the final location!
# Episode 1772 reached the final location!
# Episode 1773 reached the final location!
# Episode 1774 reached the final location!
# Episode 1775 reached the final location!
# Episode 1776 reached the final location!
# Episode 1777 reached the final location!
# Episode 1778 reached the final location!
# Episode 1779 reached the final location!
# Episode 1780 reached the final location!
# Episode 1781 reached the final location!
# Episode 1782 reached the final location!
# Episode 1783 reached the final location!
# Episode 1784 reached the final location!
# Episode 1785 reached the final location!
# Episode 1786 reached the final location!
# Episode 1787 reached the final location!
# Episode 1788 reached the final location!
# Episode 1789 reached the final location!
# Episode 1790 reached the final location!
# Episode 1791 reached the final location!
# Episode 1792 reached the final location!
# Episode 1793 reached the final location!
# Episode 1794 reached the final location!
# Episode 1795 reached the final location!
# Episode 1796 reached the final location!
# Episode 1797 reached the final location!
# Episode 1798 reached the final location!
# Episode 1799 reached the final location!
# Episode 1800 reached the final location!
# Episode 1801 reached the final location!
# Episode 1802 reached the final location!
# Episode 1803 reached the final location!
# Episode 1804 reached the final location!
# Episode 1805 reached the final location!
# Episode 1806 reached the final location!
# Episode 1807 reached the final location!
# Episode 1808 reached the final location!
# Episode 1809 reached the final location!
# Episode 1810 reached the final location!
# Episode 1811 reached the final location!
# Episode 1812 reached the final location!
# Episode 1813 reached the final location!
# Episode 1814 reached the final location!
# Episode 1815 reached the final location!
# Episode 1816 reached the final location!
# Episode 1817 reached the final location!
# Episode 1818 reached the final location!
# Episode 1819 reached the final location!
# Episode 1820 reached the final location!
# Episode 1821 reached the final location!
# Episode 1822 reached the final location!
# Episode 1823 reached the final location!
# Episode 1824 reached the final location!
# Episode 1825 reached the final location!
# Episode 1826 reached the final location!
# Episode 1827 reached the final location!
# Episode 1828 reached the final location!
# Episode 1829 reached the final location!
# Episode 1830 reached the final location!
# Episode 1831 reached the final location!
# Episode 1832 reached the final location!
# Episode 1833 reached the final location!
# Episode 1834 reached the final location!
# Episode 1835 reached the final location!
# Episode 1836 reached the final location!
# Episode 1837 reached the final location!
# Episode 1838 reached the final location!
# Episode 1839 reached the final location!
# Episode 1840 reached the final location!
# Episode 1841 reached the final location!
# Episode 1842 reached the final location!
# Episode 1843 reached the final location!
# Episode 1844 reached the final location!
# Episode 1845 reached the final location!
# Episode 1846 reached the final location!
# Episode 1847 reached the final location!
# Episode 1848 reached the final location!
# Episode 1849 reached the final location!
# Episode 1850 reached the final location!
# Episode 1851 reached the final location!
# Episode 1852 reached the final location!
# Episode 1853 reached the final location!
# Episode 1854 reached the final location!
# Episode 1855 reached the final location!
# Episode 1856 reached the final location!
# Episode 1857 reached the final location!
# Episode 1858 reached the final location!
# Episode 1859 reached the final location!
# Episode 1860 reached the final location!
# Episode 1861 reached the final location!
# Episode 1862 reached the final location!
# Episode 1863 reached the final location!
# Episode 1864 reached the final location!
# Episode 1865 reached the final location!
# Episode 1866 reached the final location!
# Episode 1867 reached the final location!
# Episode 1868 reached the final location!
# Episode 1869 reached the final location!
# Episode 1870 reached the final location!
# Episode 1871 reached the final location!
# Episode 1872 reached the final location!
# Episode 1873 reached the final location!
# Episode 1874 reached the final location!
# Episode 1875 reached the final location!
# Episode 1876 reached the final location!
# Episode 1877 reached the final location!
# Episode 1878 reached the final location!
# Episode 1879 reached the final location!
# Episode 1880 reached the final location!
# Episode 1881 reached the final location!
# Episode 1882 reached the final location!
# Episode 1883 reached the final location!
# Episode 1884 reached the final location!
# Episode 1885 reached the final location!
# Episode 1886 reached the final location!
# Episode 1887 reached the final location!
# Episode 1888 reached the final location!
# Episode 1889 reached the final location!
# Episode 1890 reached the final location!
# Episode 1891 reached the final location!
# Episode 1892 reached the final location!
# Episode 1893 reached the final location!
# Episode 1894 reached the final location!
# Episode 1895 reached the final location!
# Episode 1896 reached the final location!
# Episode 1897 reached the final location!
# Episode 1898 reached the final location!
# Episode 1899 reached the final location!
# Episode 1900 reached the final location!
# Episode 1901 reached the final location!
# Episode 1902 reached the final location!
# Episode 1903 reached the final location!
# Episode 1904 reached the final location!
# Episode 1905 reached the final location!
# Episode 1906 reached the final location!
# Episode 1907 reached the final location!
# Episode 1908 reached the final location!
# Episode 1909 reached the final location!
# Episode 1910 reached the final location!
# Episode 1911 reached the final location!
# Episode 1912 reached the final location!
# Episode 1913 reached the final location!
# Episode 1914 reached the final location!
# Episode 1915 reached the final location!
# Episode 1916 reached the final location!
# Episode 1917 reached the final location!
# Episode 1918 reached the final location!
# Episode 1919 reached the final location!
# Episode 1920 reached the final location!
# Episode 1921 reached the final location!
# Episode 1922 reached the final location!
# Episode 1923 reached the final location!
# Episode 1924 reached the final location!
# Episode 1925 reached the final location!
# Episode 1926 reached the final location!
# Episode 1927 reached the final location!
# Episode 1928 reached the final location!
# Episode 1929 reached the final location!
# Episode 1930 reached the final location!
# Episode 1931 reached the final location!
# Episode 1932 reached the final location!
# Episode 1933 reached the final location!
# Episode 1934 reached the final location!
# Episode 1935 reached the final location!
# Episode 1936 reached the final location!
# Episode 1937 reached the final location!
# Episode 1938 reached the final location!
# Episode 1939 reached the final location!
# Episode 1940 reached the final location!
# Episode 1941 reached the final location!
# Episode 1942 reached the final location!
# Episode 1943 reached the final location!
# Episode 1944 reached the final location!
# Episode 1945 reached the final location!
# Episode 1946 reached the final location!
# Episode 1947 reached the final location!
# Episode 1948 reached the final location!
# Episode 1949 reached the final location!
# Episode 1950 reached the final location!
# Episode 1951 reached the final location!
# Episode 1952 reached the final location!
# Episode 1953 reached the final location!
# Episode 1954 reached the final location!
# Episode 1955 reached the final location!
# Episode 1956 reached the final location!
# Episode 1957 reached the final location!
# Episode 1958 reached the final location!
# Episode 1959 reached the final location!
# Episode 1960 reached the final location!
# Episode 1961 reached the final location!
# Episode 1962 reached the final location!
# Episode 1963 reached the final location!
# Episode 1964 reached the final location!
# Episode 1965 reached the final location!
# Episode 1966 reached the final location!
# Episode 1967 reached the final location!
# Episode 1968 reached the final location!
# Episode 1969 reached the final location!
# Episode 1970 reached the final location!
# Episode 1971 reached the final location!
# Episode 1972 reached the final location!
# Episode 1973 reached the final location!
# Episode 1974 reached the final location!
# Episode 1975 reached the final location!
# Episode 1976 reached the final location!
# Episode 1977 reached the final location!
# Episode 1978 reached the final location!
# Episode 1979 reached the final location!
# Episode 1980 reached the final location!
# Episode 1981 reached the final location!
# Episode 1982 reached the final location!
# Episode 1983 reached the final location!
# Episode 1984 reached the final location!
# Episode 1985 reached the final location!
# Episode 1986 reached the final location!
# Episode 1987 reached the final location!
# Episode 1988 reached the final location!
# Episode 1989 reached the final location!
# Episode 1990 reached the final location!
# Episode 1991 reached the final location!
# Episode 1992 reached the final location!
# Episode 1993 reached the final location!
# Episode 1994 reached the final location!
# Episode 1995 reached the final location!
# Episode 1996 reached the final location!
# Episode 1997 reached the final location!
# Episode 1998 reached the final location!
# Episode 1999 reached the final location!
# Training complete!
# Final Q-table sample:
# [[ 7.75477422e-07 -1.60966418e-06 -1.46695587e-06  3.06177825e-08]
#  [ 6.11931102e-07 -1.08915151e-06 -1.55131773e-07  9.09962229e-07]
#  [ 1.00535185e-06 -6.08715581e-07 -1.03070109e-06  5.23822604e-09]
#  [-1.76937984e-07 -5.61912350e-08 -1.56035203e-06  1.20321389e-06]
#  [-6.03254199e-07  1.23722268e-07  1.32910808e-07 -1.83653090e-06]]
# Number of successful episodes: 1540 out of 2000
# Last successful episode: 1999
# Total reward over all episodes: 317000

# %%
print(f"Total reward after training: {total_reward}, total Explore rate after training: {explore_rate}")
# Out:
# Total reward after training: 317000, total Explore rate after training: 0.1

# %% [markdown]
# ## Let's see one episode

# %%
#now we can show one episode

tmp_env.manual_mode = False # we want to see the messages

image_samples = []  # Array to store images

observation = tmp_env.reset()
state_0 = tmp_env.get_1d_state()
total_reward = 0

for episodes in range(MAX_STEPS_PER_EPISODE):
    img = tmp_env.render()
    if episodes % 5 == 0:  # Save every 5th frame
        image_samples.append(img)

    action = update_action(tmp_env, state_0, explore_rate, Q=Q_test)
    obv, reward, done, info = tmp_env.step(action)
    state_1 = tmp_env.get_1d_state()
    state_0 = state_1

    total_reward += reward
    if done:
        break

print(f"Total_reward: ", total_reward)


# self.observation.shape[0]
# Out:
# Total_reward:  9200

# %% [markdown]
# ### Simple animation of agent movement in one episode

# %%
# let's make an animation of this, because it's fun
# nothing for you to do here - just run the code

import os
import matplotlib.animation as animation
if len(image_samples) == 0:
    raise ValueError("No image samples were collected for animation.")
    
height = img.shape[0]
width = img.shape[1]

output_folder = 'output_stuff'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


fig = plt.figure()
imgs = []
for im_arr in image_samples:
    im = plt.imshow(im_arr, animated=True)
    imgs.append([im])

animate = animation.ArtistAnimation(fig, imgs, interval=80, blit=True, repeat_delay=1000)
filename_gif = os.path.join(output_folder, 'animation_test.gif')
animate.save(filename_gif)
plt.show()

"""fig2 = plt.figure()
imgs_last = []
for im_arr in last_episode_frames:
    im = plt.imshow(im_arr, animated=True)
    imgs_last.append([im])

animate = animation.ArtistAnimation(fig2, imgs_last, interval=80, blit=True, repeat_delay=1000)
file_last_episode_gif = os.path.join(output_folder, 'last_episode_animation.gif')
animate.save(file_last_episode_gif)
plt.show()
"""
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# "fig2 = plt.figure()\nimgs_last = []\nfor im_arr in last_episode_frames:\n    im = plt.imshow(im_arr, animated=True)\n    imgs_last.append([im])\n\nanimate = animation.ArtistAnimation(fig2, imgs_last, interval=80, blit=True, repeat_delay=1000)\nfile_last_episode_gif = os.path.join(output_folder, 'last_episode_animation.gif')\nanimate.save(file_last_episode_gif)\nplt.show()\n"
